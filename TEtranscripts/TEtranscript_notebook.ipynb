# %% [markdown]
# # Setup for TEtranscripts pipeline on google cloud
# https://github.com/mhammell-laboratory/TEtranscripts

# %%
WRKDIR = '/local/directory/for/files'
DOWNLOADDIR = '{}/pipelinedownloads'.format(WRKDIR)
GCOUTPUT = 'gs://bucketname/output'
USER = 'myuser'
PROJECT_ID = 'projectid'
GCRESOURCES = 'gs://bucketname/TEtranscriptsresources'
COHORT = 'cohort'

# %% [markdown]
# # (1) Get gene annotation file
# ### download the hg38 gene annotation file: http://genome.ucsc.edu/cgi-bin/hgTables
# ### enter file name, select gtf output format, and hit get output

# %% [markdown]
# ### run the following to push to google cloud

# %%
print('copy and run locally:')
print('gsutil cp {}/hg38_gene_annotation.gtf {}/'.format(DOWNLOADDIR, GCRESOURCES))
# Out:
# copy and run locally:
# gsutil cp /local/path/for/files/pipelinedownloads/hg38_gene_annotation.gtf gs://bucketname/TEtranscriptsresources/

# %% [markdown]
# # (2) Use (a) provided transposable element annotation file or (b) generate own from DFAM data or (c) make custom from lifted over hg19 elements

# %% [markdown]
# ### (a) Download the transposable elements annotation file and push to google cloud (if not generating on your own)

# %%
print('copy and run locally:')
print("curl http://labshare.cshl.edu/shares/mhammelllab/www-data/TEtranscripts/TE_GTF/hg38_rmsk_TE.gtf.gz -o {}/hg38_rmsk_TE.gtf.gz".format(DOWNLOADDIR))
print("gunzip {}/hg38_rmsk_TE.gtf.gz".format(DOWNLOADDIR))
print("gsutil cp {}/hg38_rmsk_TE.gtf {}/".format(DOWNLOADDIR, GCRESOURCES))
# Out:
# copy and run locally:
# curl http://labshare.cshl.edu/shares/mhammelllab/www-data/TEtranscripts/TE_GTF/hg38_rmsk_TE.gtf.gz -o /local/path/for/files/pipelinedownloads/hg38_rmsk_TE.gtf.gz
# gunzip /local/path/for/files/pipelinedownloads/hg38_rmsk_TE.gtf.gz
# gsutil cp /local/path/for/files/pipelinedownloads/hg38_rmsk_TE.gtf gs://bucketname/TEtranscriptsresources/

# %% [markdown]
# ### (b) Build full hg38 transposable element tsv annotation file to pass to PERL script that creates the GTF we want

# %%
print("curl https://www.dfam.org/releases/Dfam_3.1/annotations/hg38/hg38_dfam.nrph.hits.gz -o {}/hg38_dfam.nrph.hits.gz".format(DOWNLOADDIR))

print("gunzip {}/hg38_dfam.nrph.hits.gz".format(DOWNLOADDIR))
# Out:
# curl https://www.dfam.org/releases/Dfam_3.1/annotations/hg38/hg38_dfam.nrph.hits.gz -o /local/path/for/files/pipelinedownloads/hg38_dfam.nrph.hits.gz
# gunzip /local/path/for/files/pipelinedownloads/hg38_dfam.nrph.hits.gz

# %% [markdown]
# read the hits file and check the size

# %%
import pandas as pd

hits = pd.read_csv("{}/hg38_dfam.nrph.hits".format(DOWNLOADDIR), sep='\t')

print(hits.shape)
hits.head()
# Out:
# (5657545, 15)
#   #seq_name   family_acc  family_name   bits        e-value  bias  hmm-st  \
# 0      chr1  DF0001137.4         TAR1  355.0  1.100000e-103  98.4    1206
# 1      chr1  DF0001137.4         TAR1  558.7  4.100000e-165  71.5     466
# 2      chr1  DF0000279.4  L1MC4a_3end   64.0   6.900000e-16   9.4     195
# 3      chr1  DF0000878.4        MER5B   35.7   1.300000e-05   7.2       1
# 4      chr1  DF0001253.2     MIR1_Amn   30.9   3.100000e-04   6.8      57
#
#    hmm-en strand  ali-st  ali-en  env-st  env-en     sq-len  kimura_div
# 0    1716      -   10954   10464   10964   10448  248956422        8.32
# 1    1114      -   11463   10826   11482   10810  248956422        6.74
# 2     395      -   11676   11502   11696   11480  248956422       17.98
# 3     105      -   11780   11677   11780   11657  248956422       22.20
# 4     149      -   15353   15265   15376   15248  248956422       18.87

# %% [markdown]
# get the unique accession names

# %%
import numpy as np
family_acc = hits['family_acc']

print(family_acc.size)
print(family_acc.head())

family_acc = np.unique(family_acc)

print(family_acc.size)
print(family_acc[:10])
# Out:
# 5657545
# 0    DF0001137.4
# 1    DF0001137.4
# 2    DF0000279.4
# 3    DF0000878.4
# 4    DF0001253.2
# Name: family_acc, dtype: object
# 1304
# ['DF0000001.4' 'DF0000002.4' 'DF0000003.4' 'DF0000004.4' 'DF0000005.4'
#  'DF0000006.4' 'DF0000007.4' 'DF0000008.4' 'DF0000010.4' 'DF0000011.4']

# %% [markdown]
# make a data frame to contain the accession names, family ids and class ids

# %%
df = pd.DataFrame(data=family_acc)

df.columns = ['DF']
print(df.shape)
print(df.head())
# Out:
# (1304, 1)
#             DF
# 0  DF0000001.4
# 1  DF0000002.4
# 2  DF0000003.4
# 3  DF0000004.4
# 4  DF0000005.4

# %% [markdown]
# use the [dfam api](https://www.dfam.org/help/api) to get the family id and class id for each accession name

# %%
import requests

url = "https://dfam.org/api/families"

df['family_id'] = [""] * len(df.index)
df['class_id'] = [""] * len(df.index)

print(df.head())
for row in df.itertuples():
    params = {
    "format": "full",
    "name_accession": row.DF.split(".",1)[0]

    }
    
    response = requests.get(url, params=params)
    results = response.json()["results"]
    print(row.Index)
    
    #repeat_subtype_name corresponds to family_id
    df.loc[row.Index,"family_id"] = results[0]["repeat_subtype_name"]

    #repeat_type_name corresponds to class_id
    df.loc[row.Index, "class_id"] = results[0]["repeat_type_name"]
    
    #if either is none then set it to some no_id value
    if(results[0]["repeat_subtype_name"] is None):
        df.loc[row.Index,"family_id"] = "no_family_id"
    
    if(results[0]["repeat_type_name"] is None):
        df.loc[row.Index, "class_id"] = "no_class_id"
    #if(len(results)!=1):
        #break
        
    print(df.loc[[row.Index]])
    
    
print("done")
print(df.shape)
# Out:
#             DF family_id class_id
# 0  DF0000001.4
# 1  DF0000002.4
# 2  DF0000003.4
# 3  DF0000004.4
# 4  DF0000005.4
# 0
#             DF family_id class_id
# 0  DF0000001.4       MIR     SINE
# 1
#             DF family_id class_id
# 1  DF0000002.4       Alu     SINE
# 2
#             DF family_id class_id
# 2  DF0000003.4       Alu     SINE
# 3
#             DF     family_id class_id
# 3  DF0000004.4  TcMar-Tigger      DNA
# 4
#             DF  family_id class_id
# 4  DF0000005.4  ERVL-MaLR      LTR
# 5
#             DF family_id class_id
# 5  DF0000006.4  Helitron       RC
# 6
#             DF family_id class_id
# 6  DF0000007.4       Alu     SINE
# 7
#             DF family_id class_id
# 7  DF0000008.4        L1     LINE
# 8
#             DF family_id class_id
# 8  DF0000010.4        L1     LINE
# 9
#             DF                                      family_id class_id
# 9  DF0000011.4  root;Interspersed_Repeat;Pseudogene;RNA;snRNA    snRNA
# 10
#              DF                                     family_id class_id
# 10  DF0000012.4  root;Interspersed_Repeat;Pseudogene;RNA;rRNA     rRNA
# 11
#              DF  family_id   class_id
# 11  DF0000013.4  acromeric  Satellite
# 12
#              DF    family_id   class_id
# 12  DF0000014.4  centromeric  Satellite
# 13
#              DF    family_id   class_id
# 13  DF0000015.4  centromeric  Satellite
# 14
#            DF family_id class_id
# 14  DF0000016       Alu     SINE
# 15
#            DF family_id class_id
# 15  DF0000017      ERV1      LTR
# 16
#              DF    family_id class_id
# 16  DF0000018.4  hAT-Charlie      DNA
# 17
#              DF    family_id class_id
# 17  DF0000019.4  hAT-Charlie      DNA
# 18
#              DF    family_id class_id
# 18  DF0000020.4  hAT-Charlie      DNA
# 19
#              DF    family_id class_id
# 19  DF0000021.4  hAT-Charlie      DNA
# 20
#              DF    family_id class_id
# 20  DF0000022.4  hAT-Charlie      DNA
# 21
#              DF    family_id class_id
# 21  DF0000023.4  hAT-Charlie      DNA
# 22
#              DF    family_id class_id
# 22  DF0000024.4  hAT-Charlie      DNA
# 23
#              DF    family_id class_id
# 23  DF0000025.4  hAT-Charlie      DNA
# 24
#              DF    family_id class_id
# 24  DF0000026.4  hAT-Charlie      DNA
# 25
#              DF    family_id class_id
# 25  DF0000027.4  hAT-Charlie      DNA
# 26
#              DF     family_id class_id
# 26  DF0000028.4  TcMar-Tigger      DNA
# 27
#              DF    family_id   class_id
# 27  DF0000029.4  centromeric  Satellite
# 28
#              DF family_id class_id
# 28  DF0000034.4       Alu     SINE
# 29
#              DF family_id class_id
# 29  DF0000035.4       Alu     SINE
# 30
#              DF family_id class_id
# 30  DF0000036.4       Alu     SINE
# 31
#              DF family_id class_id
# 31  DF0000037.4       Alu     SINE
# 32
#              DF family_id class_id
# 32  DF0000038.4       Alu     SINE
# 33
#              DF family_id class_id
# 33  DF0000039.4       Alu     SINE
# 34
#              DF family_id class_id
# 34  DF0000040.4       Alu     SINE
# 35
#              DF family_id class_id
# 35  DF0000041.4       Alu     SINE
# 36
#              DF family_id class_id
# 36  DF0000042.4       Alu     SINE
# 37
#              DF family_id class_id
# 37  DF0000043.4       Alu     SINE
# 38
#              DF family_id class_id
# 38  DF0000044.4       Alu     SINE
# 39
#              DF family_id class_id
# 39  DF0000045.4       Alu     SINE
# 40
#              DF family_id class_id
# 40  DF0000046.4       Alu     SINE
# 41
#              DF family_id class_id
# 41  DF0000047.4       Alu     SINE
# 42
#              DF family_id class_id
# 42  DF0000048.4       Alu     SINE
# 43
#              DF family_id class_id
# 43  DF0000049.4       Alu     SINE
# 44
#              DF family_id class_id
# 44  DF0000050.4       Alu     SINE
# 45
#              DF family_id class_id
# 45  DF0000051.4       Alu     SINE
# 46
#              DF family_id class_id
# 46  DF0000052.4       Alu     SINE
# 47
#              DF family_id class_id
# 47  DF0000053.4       Alu     SINE
# 48
#              DF family_id class_id
# 48  DF0000054.4       Alu     SINE
# 49
#              DF family_id class_id
# 49  DF0000055.4       Alu     SINE
# 50
#              DF family_id class_id
# 50  DF0000056.4       Alu     SINE
# 51
#              DF family_id class_id
# 51  DF0000057.4       Alu     SINE
# 52
#              DF family_id class_id
# 52  DF0000058.4       Alu     SINE
# 53
#              DF family_id class_id
# 53  DF0000060.4       Alu     SINE
# 54
#              DF family_id class_id
# 54  DF0000063.4       Alu     SINE
# 55
#              DF family_id class_id
# 55  DF0000064.4       Alu     SINE
# 56
#              DF family_id class_id
# 56  DF0000065.4       Alu     SINE
# 57
#              DF family_id class_id
# 57  DF0000066.4       Alu     SINE
# 58
#              DF  family_id class_id
# 58  DF0000067.4  5S-Deu-L2     SINE
# 59
#              DF family_id class_id
# 59  DF0000068.4  tRNA-Deu     SINE
# 60
#              DF   family_id class_id
# 60  DF0000069.4  hAT-Tip100      DNA
# 61
#              DF   family_id class_id
# 61  DF0000070.4  hAT-Tip100      DNA
# 62
#              DF   family_id class_id
# 62  DF0000071.4  hAT-Tip100      DNA
# 63
#              DF   family_id class_id
# 63  DF0000072.4  hAT-Tip100      DNA
# 64
#              DF family_id class_id
# 64  DF0000073.4       Alu     SINE
# 65
#              DF      family_id class_id
# 65  DF0000074.4  hAT-Blackjack      DNA
# 66
#              DF                     family_id   class_id
# 66  DF0000075.4  root;Tandem_Repeat;Satellite  Satellite
# 67
#              DF                     family_id   class_id
# 67  DF0000076.4  root;Tandem_Repeat;Satellite  Satellite
# 68
#              DF                     family_id   class_id
# 68  DF0000077.4  root;Tandem_Repeat;Satellite  Satellite
# 69
#              DF                     family_id   class_id
# 69  DF0000078.4  root;Tandem_Repeat;Satellite  Satellite
# 70
#              DF                     family_id   class_id
# 70  DF0000079.4  root;Tandem_Repeat;Satellite  Satellite
# 71
#              DF    family_id class_id
# 71  DF0000080.4  hAT-Charlie      DNA
# 72
#              DF    family_id class_id
# 72  DF0000081.4  hAT-Charlie      DNA
# 73
#              DF    family_id class_id
# 73  DF0000082.4  hAT-Charlie      DNA
# 74
#              DF    family_id class_id
# 74  DF0000083.4  hAT-Charlie      DNA
# 75
#              DF    family_id class_id
# 75  DF0000084.4  hAT-Charlie      DNA
# 76
#              DF    family_id class_id
# 76  DF0000085.4  hAT-Charlie      DNA
# 77
#              DF    family_id class_id
# 77  DF0000086.4  hAT-Charlie      DNA
# 78
#              DF    family_id class_id
# 78  DF0000087.4  hAT-Charlie      DNA
# 79
#              DF    family_id class_id
# 79  DF0000088.4  hAT-Charlie      DNA
# 80
#              DF    family_id class_id
# 80  DF0000089.4  hAT-Charlie      DNA
# 81
#              DF    family_id class_id
# 81  DF0000090.4  hAT-Charlie      DNA
# 82
#              DF    family_id class_id
# 82  DF0000091.4  hAT-Charlie      DNA
# 83
#              DF    family_id class_id
# 83  DF0000092.4  hAT-Charlie      DNA
# 84
#              DF    family_id class_id
# 84  DF0000093.4  hAT-Charlie      DNA
# 85
#              DF    family_id class_id
# 85  DF0000094.4  hAT-Charlie      DNA
# 86
#              DF    family_id class_id
# 86  DF0000095.4  hAT-Charlie      DNA
# 87
#              DF    family_id class_id
# 87  DF0000096.4  hAT-Charlie      DNA
# 88
#              DF    family_id class_id
# 88  DF0000097.4  hAT-Charlie      DNA
# 89
#              DF    family_id class_id
# 89  DF0000098.4  hAT-Charlie      DNA
# 90
#              DF    family_id class_id
# 90  DF0000099.4  hAT-Charlie      DNA
# 91
#              DF    family_id class_id
# 91  DF0000100.4  hAT-Charlie      DNA
# 92
#              DF    family_id class_id
# 92  DF0000101.4  hAT-Charlie      DNA
# 93
#              DF    family_id class_id
# 93  DF0000102.4  hAT-Charlie      DNA
# 94
#              DF    family_id class_id
# 94  DF0000103.4  hAT-Charlie      DNA
# 95
#              DF    family_id class_id
# 95  DF0000104.4  hAT-Charlie      DNA
# 96
#              DF    family_id class_id
# 96  DF0000105.4  hAT-Charlie      DNA
# 97
#              DF    family_id class_id
# 97  DF0000106.4  hAT-Charlie      DNA
# 98
#              DF    family_id class_id
# 98  DF0000107.4  hAT-Charlie      DNA
# 99
#              DF    family_id class_id
# 99  DF0000108.4  hAT-Charlie      DNA
# 100
#               DF    family_id class_id
# 100  DF0000109.4  hAT-Charlie      DNA
# 101
#               DF family_id class_id
# 101  DF0000110.4       CR1     LINE
# 102
#               DF                     family_id   class_id
# 102  DF0000111.4  root;Tandem_Repeat;Satellite  Satellite
# 103
#               DF  family_id class_id
# 103  DF0000113.4  TcMar-Tc1      DNA
# 104
#             DF family_id class_id
# 104  DF0000114      ERV1      LTR
# 105
#             DF family_id class_id
# 105  DF0000115      ERV1      LTR
# 106
#               DF family_id class_id
# 106  DF0000116.4      ERVL      LTR
# 107
#               DF family_id class_id
# 107  DF0000117.4      ERVL      LTR
# 108
#               DF family_id class_id
# 108  DF0000118.4      ERVL      LTR
# 109
#               DF family_id class_id
# 109  DF0000119.4      ERVL      LTR
# 110
#               DF family_id class_id
# 110  DF0000120.4      ERVL      LTR
# 111
#               DF                                          family_id class_id
# 111  DF0000121.4  root;Interspersed_Repeat;Transposable_Element;...      DNA
# 112
#               DF                                          family_id class_id
# 112  DF0000122.4  root;Interspersed_Repeat;Transposable_Element;...      DNA
# 113
#               DF                                          family_id class_id
# 113  DF0000123.4  root;Interspersed_Repeat;Transposable_Element;...      DNA
# 114
#               DF                                          family_id class_id
# 114  DF0000124.4  root;Interspersed_Repeat;Transposable_Element;...      DNA
# 115
#               DF                                          family_id class_id
# 115  DF0000125.4  root;Interspersed_Repeat;Transposable_Element;...      DNA
# 116
#               DF                                          family_id class_id
# 116  DF0000126.4  root;Interspersed_Repeat;Transposable_Element;...      DNA
# 117
#               DF                                          family_id class_id
# 117  DF0000127.4  root;Interspersed_Repeat;Transposable_Element;...      DNA
# 118
#               DF                                          family_id class_id
# 118  DF0000128.4  root;Interspersed_Repeat;Transposable_Element;...      DNA
# 119
#               DF                         family_id class_id
# 119  DF0000129.4  root;Interspersed_Repeat;Unknown  Unknown
# 120
#               DF  family_id class_id
# 120  DF0000130.4  Crypton-A      DNA
# 121
#               DF  family_id class_id
# 121  DF0000131.4  Crypton-A      DNA
# 122
#               DF family_id class_id
# 122  DF0000132.4   Crypton      DNA
# 123
#               DF family_id class_id
# 123  DF0000133.4   Crypton      DNA
# 124
#               DF family_id class_id
# 124  DF0000134.4   Crypton      DNA
# 125
#               DF family_id class_id
# 125  DF0000135.4   Crypton      DNA
# 126
#               DF family_id class_id
# 126  DF0000136.4   Crypton      DNA
# 127
#               DF                                          family_id class_id
# 127  DF0000137.4  root;Interspersed_Repeat;Transposable_Element;...      DNA
# 128
#               DF family_id class_id
# 128  DF0000138.4     TcMar      DNA
# 129
#               DF                                          family_id class_id
# 129  DF0000139.4  root;Interspersed_Repeat;Transposable_Element;...      DNA
# 130
#               DF                                          family_id class_id
# 130  DF0000140.4  root;Interspersed_Repeat;Transposable_Element;...      DNA
# 131
#               DF                                          family_id class_id
# 131  DF0000141.4  root;Interspersed_Repeat;Transposable_Element;...      DNA
# 132
#               DF family_id class_id
# 132  DF0000142.4       Alu     SINE
# 133
#               DF family_id class_id
# 133  DF0000143.4       Alu     SINE
# 134
#               DF family_id class_id
# 134  DF0000144.4       Alu     SINE
# 135
#               DF   family_id class_id
# 135  DF0000145.4  hAT-Tip100      DNA
# 136
#               DF   family_id class_id
# 136  DF0000146.4  hAT-Tip100      DNA
# 137
#               DF family_id class_id
# 137  DF0000147.4       Alu     SINE
# 138
#               DF    family_id   class_id
# 138  DF0000148.4  centromeric  Satellite
# 139
#               DF    family_id   class_id
# 139  DF0000150.4  centromeric  Satellite
# 140
#               DF    family_id   class_id
# 140  DF0000152.4  centromeric  Satellite
# 141
#               DF family_id class_id
# 141  DF0000154.4        L1     LINE
# 142
#               DF family_id class_id
# 142  DF0000155.4        L1     LINE
# 143
#               DF family_id class_id
# 143  DF0000156.4        L1     LINE
# 144
#               DF family_id class_id
# 144  DF0000157.4        L1     LINE
# 145
#               DF family_id class_id
# 145  DF0000158.4  Helitron       RC
# 146
#               DF family_id class_id
# 146  DF0000159.4  Helitron       RC
# 147
#               DF family_id class_id
# 147  DF0000160.4  Helitron       RC
# 148
#             DF family_id class_id
# 148  DF0000161      ERV1      LTR
# 149
#               DF family_id class_id
# 149  DF0000162.4      ERVL      LTR
# 150
#             DF family_id class_id
# 150  DF0000163      ERV1      LTR
# 151
#               DF family_id class_id
# 151  DF0000164.4      ERV1      LTR
# 152
#               DF family_id class_id
# 152  DF0000165.4      ERV1      LTR
# 153
#               DF family_id class_id
# 153  DF0000166.4      ERV1      LTR
# 154
#               DF family_id class_id
# 154  DF0000167.4      ERV1      LTR
# 155
#               DF family_id class_id
# 155  DF0000168.4      ERV1      LTR
# 156
#             DF family_id class_id
# 156  DF0000169      ERV1      LTR
# 157
#             DF family_id class_id
# 157  DF0000170      ERV1      LTR
# 158
#               DF family_id class_id
# 158  DF0000171.4      ERV1      LTR
# 159
#               DF family_id class_id
# 159  DF0000172.4      ERV1      LTR
# 160
#             DF family_id class_id
# 160  DF0000173      ERV1      LTR
# 161
#             DF family_id class_id
# 161  DF0000174      ERV1      LTR
# 162
#             DF family_id class_id
# 162  DF0000175      ERV1      LTR
# 163
#               DF family_id class_id
# 163  DF0000176.4      ERV1      LTR
# 164
#               DF family_id class_id
# 164  DF0000177.4      ERV1      LTR
# 165
#               DF family_id class_id
# 165  DF0000178.4      ERV1      LTR
# 166
#             DF family_id class_id
# 166  DF0000179      ERV1      LTR
# 167
#               DF family_id class_id
# 167  DF0000180.4      ERV1      LTR
# 168
#             DF family_id class_id
# 168  DF0000181      ERV1      LTR
# 169
#             DF family_id class_id
# 169  DF0000182      ERV1      LTR
# 170
#             DF family_id class_id
# 170  DF0000183      ERV1      LTR
# 171
#             DF family_id class_id
# 171  DF0000184      ERV1      LTR
# 172
#             DF family_id class_id
# 172  DF0000185      ERV1      LTR
# 173
#             DF family_id class_id
# 173  DF0000186      ERV1      LTR
# 174
#               DF family_id class_id
# 174  DF0000187.4      ERV1      LTR
# 175
#             DF family_id class_id
# 175  DF0000188      ERVK      LTR
# 176
#             DF family_id class_id
# 176  DF0000189      ERVK      LTR
# 177
#             DF family_id class_id
# 177  DF0000190      ERVK      LTR
# 178
#             DF family_id class_id
# 178  DF0000191      ERVK      LTR
# 179
#               DF family_id class_id
# 179  DF0000192.4      ERVK      LTR
# 180
#             DF family_id class_id
# 180  DF0000193      ERVK      LTR
# 181
#             DF family_id class_id
# 181  DF0000194      ERVK      LTR
# 182
#             DF family_id class_id
# 182  DF0000195      ERVK      LTR
# 183
#               DF family_id class_id
# 183  DF0000196.4      ERVK      LTR
# 184
#               DF family_id class_id
# 184  DF0000197.4      ERVK      LTR
# 185
#               DF family_id class_id
# 185  DF0000198.4      ERVL      LTR
# 186
#               DF family_id class_id
# 186  DF0000199.4      ERVL      LTR
# 187
#               DF family_id class_id
# 187  DF0000200.4      ERVL      LTR
# 188
#               DF family_id class_id
# 188  DF0000201.4      ERVL      LTR
# 189
#               DF family_id class_id
# 189  DF0000202.4      ERVL      LTR
# 190
#               DF family_id class_id
# 190  DF0000203.4      ERVL      LTR
# 191
#             DF family_id class_id
# 191  DF0000204      ERV1      LTR
# 192
#             DF family_id class_id
# 192  DF0000205      ERV1      LTR
# 193
#               DF    family_id   class_id
# 193  DF0000206.4  centromeric  Satellite
# 194
#               DF                     family_id   class_id
# 194  DF0000207.4  root;Tandem_Repeat;Satellite  Satellite
# 195
#               DF                     family_id   class_id
# 195  DF0000209.4  root;Tandem_Repeat;Satellite  Satellite
# 196
#               DF                     family_id   class_id
# 196  DF0000210.4  root;Tandem_Repeat;Satellite  Satellite
# 197
#               DF                     family_id   class_id
# 197  DF0000211.4  root;Tandem_Repeat;Satellite  Satellite
# 198
#               DF      family_id class_id
# 198  DF0000212.4  TcMar-Mariner      DNA
# 199
#               DF      family_id class_id
# 199  DF0000213.4  TcMar-Mariner      DNA
# 200
#             DF family_id class_id
# 200  DF0000214      ERV1      LTR
# 201
#               DF family_id class_id
# 201  DF0000215.4      ERV1      LTR
# 202
#             DF family_id class_id
# 202  DF0000216      ERV1      LTR
# 203
#             DF family_id class_id
# 203  DF0000217      ERV1      LTR
# 204
#               DF  family_id class_id
# 204  DF0000218.4  TcMar-Tc2      DNA
# 205
#               DF  family_id class_id
# 205  DF0000219.4  TcMar-Tc2      DNA
# 206
#               DF  family_id class_id
# 206  DF0000220.4  TcMar-Tc2      DNA
# 207
#               DF  family_id class_id
# 207  DF0000221.4  TcMar-Tc2      DNA
# 208
#               DF  family_id class_id
# 208  DF0000222.4  TcMar-Tc2      DNA
# 209
#               DF  family_id class_id
# 209  DF0000223.4  TcMar-Tc2      DNA
# 210
#               DF  family_id class_id
# 210  DF0000224.4  TcMar-Tc2      DNA
# 211
#               DF family_id class_id
# 211  DF0000225.4        L1     LINE
# 212
#               DF family_id class_id
# 212  DF0000226.4        L1     LINE
# 213
#               DF family_id class_id
# 213  DF0000227.4        L1     LINE
# 214
#               DF family_id class_id
# 214  DF0000228.4        L1     LINE
# 215
#               DF family_id class_id
# 215  DF0000229.4        L1     LINE
# 216
#               DF family_id class_id
# 216  DF0000230.4        L1     LINE
# 217
#               DF family_id class_id
# 217  DF0000231.4      ERV1      LTR
# 218
#               DF family_id class_id
# 218  DF0000232.4        L1     LINE
# 219
#               DF family_id class_id
# 219  DF0000233.4        L1     LINE
# 220
#               DF family_id class_id
# 220  DF0000234.4        L1     LINE
# 221
#               DF family_id class_id
# 221  DF0000235.4      ERV1      LTR
# 222
#               DF family_id class_id
# 222  DF0000236.4        L1     LINE
# 223
#               DF family_id class_id
# 223  DF0000237.4        L1     LINE
# 224
#               DF family_id class_id
# 224  DF0000238.4        L1     LINE
# 225
#               DF family_id class_id
# 225  DF0000239.4        L1     LINE
# 226
#               DF family_id class_id
# 226  DF0000240.4        L1     LINE
# 227
#               DF family_id class_id
# 227  DF0000241.4        L1     LINE
# 228
#               DF family_id class_id
# 228  DF0000242.4        L1     LINE
# 229
#               DF family_id class_id
# 229  DF0000243.4        L1     LINE
# 230
#               DF family_id class_id
# 230  DF0000244.4        L1     LINE
# 231
#               DF family_id class_id
# 231  DF0000245.4        L1     LINE
# 232
#               DF family_id class_id
# 232  DF0000246.4        L1     LINE
# 233
#               DF family_id class_id
# 233  DF0000247.4        L1     LINE
# 234
#               DF family_id class_id
# 234  DF0000248.4        L1     LINE
# 235
#               DF family_id class_id
# 235  DF0000249.4        L1     LINE
# 236
#               DF family_id class_id
# 236  DF0000250.4        L1     LINE
# 237
#               DF family_id class_id
# 237  DF0000251.4        L1     LINE
# 238
#               DF family_id class_id
# 238  DF0000252.4        L1     LINE
# 239
#               DF family_id class_id
# 239  DF0000253.4        L1     LINE
# 240
#               DF family_id class_id
# 240  DF0000254.4        L1     LINE
# 241
#               DF family_id class_id
# 241  DF0000255.4        L1     LINE
# 242
#               DF family_id class_id
# 242  DF0000256.4        L1     LINE
# 243
#               DF family_id class_id
# 243  DF0000257.4        L1     LINE
# 244
#               DF family_id class_id
# 244  DF0000258.4        L1     LINE
# 245
#               DF family_id class_id
# 245  DF0000259.4        L1     LINE
# 246
#               DF family_id class_id
# 246  DF0000260.4        L1     LINE
# 247
#               DF family_id class_id
# 247  DF0000261.4        L1     LINE
# 248
#               DF family_id class_id
# 248  DF0000262.4        L1     LINE
# 249
#               DF family_id class_id
# 249  DF0000263.4        L1     LINE
# 250
#               DF family_id class_id
# 250  DF0000264.4        L1     LINE
# 251
#               DF family_id class_id
# 251  DF0000265.4        L1     LINE
# 252
#               DF family_id class_id
# 252  DF0000266.4        L1     LINE
# 253
#               DF family_id class_id
# 253  DF0000267.4        L1     LINE
# 254
#               DF family_id class_id
# 254  DF0000268.4        L1     LINE
# 255
#               DF family_id class_id
# 255  DF0000269.4        L1     LINE
# 256
#               DF family_id class_id
# 256  DF0000270.4        L1     LINE
# 257
#               DF family_id class_id
# 257  DF0000271.4        L1     LINE
# 258
#               DF family_id class_id
# 258  DF0000272.4        L1     LINE
# 259
#               DF family_id class_id
# 259  DF0000273.4        L1     LINE
# 260
#               DF family_id class_id
# 260  DF0000274.4        L1     LINE
# 261
#               DF family_id class_id
# 261  DF0000275.4        L1     LINE
# 262
#               DF family_id class_id
# 262  DF0000276.4        L1     LINE
# 263
#               DF family_id class_id
# 263  DF0000277.4        L1     LINE
# 264
#               DF family_id class_id
# 264  DF0000278.4        L1     LINE
# 265
#               DF family_id class_id
# 265  DF0000279.4        L1     LINE
# 266
#               DF family_id class_id
# 266  DF0000280.4        L1     LINE
# 267
#               DF family_id class_id
# 267  DF0000281.4        L1     LINE
# 268
#               DF family_id class_id
# 268  DF0000282.4        L1     LINE
# 269
#               DF family_id class_id
# 269  DF0000283.4        L1     LINE
# 270
#               DF family_id class_id
# 270  DF0000284.4        L1     LINE
# 271
#               DF family_id class_id
# 271  DF0000285.4        L1     LINE
# 272
#               DF family_id class_id
# 272  DF0000286.4        L1     LINE
# 273
#               DF family_id class_id
# 273  DF0000287.4        L1     LINE
# 274
#               DF family_id class_id
# 274  DF0000288.4        L1     LINE
# 275
#               DF family_id class_id
# 275  DF0000289.4        L1     LINE
# 276
#               DF family_id class_id
# 276  DF0000290.4        L1     LINE
# 277
#               DF family_id class_id
# 277  DF0000291.4        L1     LINE
# 278
#               DF family_id class_id
# 278  DF0000292.4        L1     LINE
# 279
#               DF family_id class_id
# 279  DF0000293.4        L1     LINE
# 280
#               DF family_id class_id
# 280  DF0000294.4        L1     LINE
# 281
#               DF family_id class_id
# 281  DF0000295.4        L1     LINE
# 282
#               DF family_id class_id
# 282  DF0000296.4        L1     LINE
# 283
#               DF family_id class_id
# 283  DF0000297.4        L1     LINE
# 284
#               DF family_id class_id
# 284  DF0000298.4        L1     LINE
# 285
#               DF family_id class_id
# 285  DF0000299.4        L1     LINE
# 286
#               DF family_id class_id
# 286  DF0000300.4        L1     LINE
# 287
#               DF family_id class_id
# 287  DF0000301.4        L1     LINE
# 288
#               DF family_id class_id
# 288  DF0000302.4        L1     LINE
# 289
#               DF family_id class_id
# 289  DF0000303.4        L1     LINE
# 290
#               DF family_id class_id
# 290  DF0000304.4        L1     LINE
# 291
#               DF family_id class_id
# 291  DF0000305.4        L1     LINE
# 292
#               DF family_id class_id
# 292  DF0000306.4        L1     LINE
# 293
#               DF family_id class_id
# 293  DF0000307.4        L1     LINE
# 294
#               DF family_id class_id
# 294  DF0000308.4        L1     LINE
# 295
#               DF family_id class_id
# 295  DF0000309.4        L1     LINE
# 296
#               DF family_id class_id
# 296  DF0000310.4        L1     LINE
# 297
#               DF family_id class_id
# 297  DF0000311.4        L1     LINE
# 298
#               DF family_id class_id
# 298  DF0000312.4        L1     LINE
# 299
#               DF family_id class_id
# 299  DF0000313.4        L1     LINE
# 300
#               DF family_id class_id
# 300  DF0000314.4        L1     LINE
# 301
#               DF family_id class_id
# 301  DF0000315.4        L1     LINE
# 302
#               DF family_id class_id
# 302  DF0000316.4        L1     LINE
# 303
#               DF family_id class_id
# 303  DF0000317.4        L1     LINE
# 304
#               DF family_id class_id
# 304  DF0000318.4        L1     LINE
# 305
#               DF family_id class_id
# 305  DF0000319.4        L1     LINE
# 306
#               DF family_id class_id
# 306  DF0000320.4        L1     LINE
# 307
#               DF family_id class_id
# 307  DF0000321.4        L1     LINE
# 308
#               DF family_id class_id
# 308  DF0000322.4        L1     LINE
# 309
#               DF family_id class_id
# 309  DF0000323.4        L1     LINE
# 310
#               DF family_id class_id
# 310  DF0000324.4        L1     LINE
# 311
#               DF family_id class_id
# 311  DF0000325.4        L1     LINE
# 312
#               DF family_id class_id
# 312  DF0000326.4        L1     LINE
# 313
#               DF family_id class_id
# 313  DF0000327.4        L1     LINE
# 314
#               DF family_id class_id
# 314  DF0000328.4        L1     LINE
# 315
#               DF family_id class_id
# 315  DF0000329.4        L1     LINE
# 316
#               DF family_id class_id
# 316  DF0000330.4        L1     LINE
# 317
#               DF family_id class_id
# 317  DF0000331.4        L1     LINE
# 318
#               DF family_id class_id
# 318  DF0000332.4        L1     LINE
# 319
#               DF family_id class_id
# 319  DF0000333.4        L1     LINE
# 320
#               DF family_id class_id
# 320  DF0000334.4        L1     LINE
# 321
#               DF family_id class_id
# 321  DF0000335.4        L1     LINE
# 322
#               DF family_id class_id
# 322  DF0000336.4        L1     LINE
# 323
#               DF family_id class_id
# 323  DF0000337.4        L1     LINE
# 324
#               DF family_id class_id
# 324  DF0000338.4        L1     LINE
# 325
#               DF family_id class_id
# 325  DF0000339.4        L1     LINE
# 326
#               DF family_id class_id
# 326  DF0000340.4        L1     LINE
# 327
#               DF family_id class_id
# 327  DF0000341.4        L1     LINE
# 328
#               DF family_id class_id
# 328  DF0000342.4        L1     LINE
# 329
#               DF family_id class_id
# 329  DF0000343.4        L1     LINE
# 330
#               DF family_id class_id
# 330  DF0000344.4        L1     LINE
# 331
#               DF family_id class_id
# 331  DF0000345.4        L1     LINE
# 332
#               DF family_id class_id
# 332  DF0000346.4        L1     LINE
# 333
#               DF family_id class_id
# 333  DF0000347.4        L1     LINE
# 334
#               DF family_id class_id
# 334  DF0000348.4        L1     LINE
# 335
#               DF family_id class_id
# 335  DF0000349.4        L1     LINE
# 336
#               DF family_id class_id
# 336  DF0000350.4        L1     LINE
# 337
#               DF family_id class_id
# 337  DF0000351.4        L1     LINE
# 338
#               DF family_id class_id
# 338  DF0000352.4        L1     LINE
# 339
#               DF family_id class_id
# 339  DF0000353.4        L1     LINE
# 340
#               DF family_id class_id
# 340  DF0000354.4        L1     LINE
# 341
#               DF family_id class_id
# 341  DF0000355.4        L1     LINE
# 342
#               DF family_id class_id
# 342  DF0000356.4        L1     LINE
# 343
#               DF family_id class_id
# 343  DF0000357.4        L1     LINE
# 344
#               DF family_id class_id
# 344  DF0000358.4        L2     LINE
# 345
#               DF family_id class_id
# 345  DF0000359.4        L2     LINE
# 346
#               DF family_id class_id
# 346  DF0000360.4        L2     LINE
# 347
#               DF family_id class_id
# 347  DF0000361.4        L2     LINE
# 348
#               DF family_id class_id
# 348  DF0000362.4       CR1     LINE
# 349
#               DF family_id class_id
# 349  DF0000363.4       CR1     LINE
# 350
#               DF family_id class_id
# 350  DF0000364.4     RTE-X     LINE
# 351
#               DF family_id class_id
# 351  DF0000365.4     RTE-X     LINE
# 352
#               DF family_id class_id
# 352  DF0000366.4     RTE-X     LINE
# 353
#               DF family_id class_id
# 353  DF0000367.4     RTE-X     LINE
# 354
#               DF family_id class_id
# 354  DF0000368.4      tRNA     SINE
# 355
#               DF family_id class_id
# 355  DF0000369.4  PiggyBac      DNA
# 356
#               DF family_id class_id
# 356  DF0000370.4      ERV1      LTR
# 357
#               DF family_id class_id
# 357  DF0000371.4      ERV1      LTR
# 358
#             DF family_id class_id
# 358  DF0000372      ERV1      LTR
# 359
#               DF                     family_id   class_id
# 359  DF0000373.4  root;Tandem_Repeat;Satellite  Satellite
# 360
#               DF family_id class_id
# 360  DF0000374.4      ERV1      LTR
# 361
#               DF family_id class_id
# 361  DF0000375.4      ERV1      LTR
# 362
#               DF family_id class_id
# 362  DF0000376.4      ERVL      LTR
# 363
#               DF family_id class_id
# 363  DF0000377.4      ERVL      LTR
# 364
#               DF family_id class_id
# 364  DF0000378.4      ERV1      LTR
# 365
#               DF family_id class_id
# 365  DF0000379.4      ERV1      LTR
# 366
#               DF family_id class_id
# 366  DF0000380.4     Gypsy      LTR
# 367
#               DF family_id class_id
# 367  DF0000381.4      ERVL      LTR
# 368
#               DF                                          family_id class_id
# 368  DF0000382.4  root;Interspersed_Repeat;Transposable_Element;...      LTR
# 369
#               DF                                          family_id class_id
# 369  DF0000383.4  root;Interspersed_Repeat;Transposable_Element;...      LTR
# 370
#               DF family_id class_id
# 370  DF0000384.4      ERVL      LTR
# 371
#               DF family_id class_id
# 371  DF0000385.4      ERVL      LTR
# 372
#               DF family_id class_id
# 372  DF0000386.4      ERVL      LTR
# 373
#               DF family_id class_id
# 373  DF0000387.4      ERVL      LTR
# 374
#               DF family_id class_id
# 374  DF0000388.4      ERVL      LTR
# 375
#               DF family_id class_id
# 375  DF0000389.4      ERV1      LTR
# 376
#               DF family_id class_id
# 376  DF0000390.4      ERV1      LTR
# 377
#               DF family_id class_id
# 377  DF0000391.4      ERV1      LTR
# 378
#               DF family_id class_id
# 378  DF0000392.4      ERV1      LTR
# 379
#               DF family_id class_id
# 379  DF0000393.4      ERV1      LTR
# 380
#               DF family_id class_id
# 380  DF0000394.4      ERV1      LTR
# 381
#               DF family_id class_id
# 381  DF0000395.4      ERV1      LTR
# 382
#               DF family_id class_id
# 382  DF0000396.4      ERV1      LTR
# 383
#               DF family_id class_id
# 383  DF0000397.4      ERV1      LTR
# 384
#               DF family_id class_id
# 384  DF0000398.4      ERV1      LTR
# 385
#               DF family_id class_id
# 385  DF0000399.4      ERV1      LTR
# 386
#               DF family_id class_id
# 386  DF0000400.4      ERV1      LTR
# 387
#               DF family_id class_id
# 387  DF0000401.4      ERV1      LTR
# 388
#               DF family_id class_id
# 388  DF0000402.4      ERV1      LTR
# 389
#               DF family_id class_id
# 389  DF0000403.4      ERV1      LTR
# 390
#               DF family_id class_id
# 390  DF0000404.4      ERV1      LTR
# 391
#               DF family_id class_id
# 391  DF0000405.4      ERV1      LTR
# 392
#               DF family_id class_id
# 392  DF0000406.4      ERVK      LTR
# 393
#               DF family_id class_id
# 393  DF0000407.4      ERVK      LTR
# 394
#               DF family_id class_id
# 394  DF0000408.4      ERVK      LTR
# 395
#               DF family_id class_id
# 395  DF0000409.4      ERVK      LTR
# 396
#               DF family_id class_id
# 396  DF0000410.4      ERVK      LTR
# 397
#               DF family_id class_id
# 397  DF0000411.4      ERVK      LTR
# 398
#               DF family_id class_id
# 398  DF0000412.4      ERVK      LTR
# 399
#               DF family_id class_id
# 399  DF0000413.4      ERV1      LTR
# 400
#               DF family_id class_id
# 400  DF0000414.4      ERVL      LTR
# 401
#               DF family_id class_id
# 401  DF0000415.4      ERVL      LTR
# 402
#               DF family_id class_id
# 402  DF0000416.4      ERVL      LTR
# 403
#               DF family_id class_id
# 403  DF0000417.4      ERVL      LTR
# 404
#               DF family_id class_id
# 404  DF0000418.4      ERVL      LTR
# 405
#               DF family_id class_id
# 405  DF0000419.4      ERVL      LTR
# 406
#               DF family_id class_id
# 406  DF0000420.4      ERVL      LTR
# 407
#               DF family_id class_id
# 407  DF0000421.4      ERVL      LTR
# 408
#               DF family_id class_id
# 408  DF0000422.4      ERVL      LTR
# 409
#               DF family_id class_id
# 409  DF0000423.4      ERVL      LTR
# 410
#               DF family_id class_id
# 410  DF0000424.4      ERVL      LTR
# 411
#               DF family_id class_id
# 411  DF0000425.4      ERVL      LTR
# 412
#               DF family_id class_id
# 412  DF0000426.4      ERVL      LTR
# 413
#               DF family_id class_id
# 413  DF0000427.4      ERV1      LTR
# 414
#               DF family_id class_id
# 414  DF0000428.4      ERVL      LTR
# 415
#               DF family_id class_id
# 415  DF0000429.4      ERVL      LTR
# 416
#               DF family_id class_id
# 416  DF0000430.4      ERVL      LTR
# 417
#               DF family_id class_id
# 417  DF0000431.4      ERV1      LTR
# 418
#               DF family_id class_id
# 418  DF0000432.4      ERV1      LTR
# 419
#               DF family_id class_id
# 419  DF0000433.4      ERV1      LTR
# 420
#               DF family_id class_id
# 420  DF0000434.4      ERV1      LTR
# 421
#               DF family_id class_id
# 421  DF0000435.4      ERV1      LTR
# 422
#               DF family_id class_id
# 422  DF0000436.4      ERV1      LTR
# 423
#               DF family_id class_id
# 423  DF0000437.4      ERV1      LTR
# 424
#               DF family_id class_id
# 424  DF0000438.4      ERV1      LTR
# 425
#               DF family_id class_id
# 425  DF0000439.4      ERV1      LTR
# 426
#               DF family_id class_id
# 426  DF0000440.4      ERV1      LTR
# 427
#               DF family_id class_id
# 427  DF0000441.4      ERV1      LTR
# 428
#               DF family_id class_id
# 428  DF0000442.4      ERV1      LTR
# 429
#               DF family_id class_id
# 429  DF0000443.4      ERV1      LTR
# 430
#               DF family_id class_id
# 430  DF0000444.4      ERV1      LTR
# 431
#               DF family_id class_id
# 431  DF0000445.4      ERV1      LTR
# 432
#               DF family_id class_id
# 432  DF0000446.4      ERV1      LTR
# 433
#               DF family_id class_id
# 433  DF0000447.4      ERV1      LTR
# 434
#               DF family_id class_id
# 434  DF0000448.4      ERV1      LTR
# 435
#               DF family_id class_id
# 435  DF0000449.4      ERV1      LTR
# 436
#               DF family_id class_id
# 436  DF0000450.4      ERV1      LTR
# 437
#               DF family_id class_id
# 437  DF0000451.4      ERV1      LTR
# 438
#               DF family_id class_id
# 438  DF0000452.4      ERV1      LTR
# 439
#               DF family_id class_id
# 439  DF0000453.4      ERVK      LTR
# 440
#               DF family_id class_id
# 440  DF0000454.4      ERVK      LTR
# 441
#               DF family_id class_id
# 441  DF0000455.4      ERVK      LTR
# 442
#               DF family_id class_id
# 442  DF0000456.4      ERVK      LTR
# 443
#               DF family_id class_id
# 443  DF0000457.4      ERVK      LTR
# 444
#               DF family_id class_id
# 444  DF0000458.4      ERVK      LTR
# 445
#               DF family_id class_id
# 445  DF0000459.4      ERVK      LTR
# 446
#               DF family_id class_id
# 446  DF0000460.4      ERVK      LTR
# 447
#               DF family_id class_id
# 447  DF0000461.4      ERVK      LTR
# 448
#               DF family_id class_id
# 448  DF0000462.4      ERV1      LTR
# 449
#               DF family_id class_id
# 449  DF0000463.4      ERV1      LTR
# 450
#               DF family_id class_id
# 450  DF0000464.4      ERV1      LTR
# 451
#               DF family_id class_id
# 451  DF0000465.4      ERV1      LTR
# 452
#               DF family_id class_id
# 452  DF0000466.4      ERV1      LTR
# 453
#               DF family_id class_id
# 453  DF0000467.4      ERV1      LTR
# 454
#               DF family_id class_id
# 454  DF0000468.4      ERV1      LTR
# 455
#               DF family_id class_id
# 455  DF0000469.4      ERV1      LTR
# 456
#               DF family_id class_id
# 456  DF0000470.4      ERV1      LTR
# 457
#               DF family_id class_id
# 457  DF0000471.4      ERV1      LTR
# 458
#               DF family_id class_id
# 458  DF0000472.4      ERV1      LTR
# 459
#               DF family_id class_id
# 459  DF0000473.4      ERV1      LTR
# 460
#               DF family_id class_id
# 460  DF0000474.4      ERV1      LTR
# 461
#               DF family_id class_id
# 461  DF0000475.4      ERV1      LTR
# 462
#               DF family_id class_id
# 462  DF0000476.4      ERV1      LTR
# 463
#               DF family_id class_id
# 463  DF0000477.4      ERV1      LTR
# 464
#               DF family_id class_id
# 464  DF0000478.4      ERV1      LTR
# 465
#               DF family_id class_id
# 465  DF0000479.4      ERV1      LTR
# 466
#               DF family_id class_id
# 466  DF0000480.4      ERV1      LTR
# 467
#               DF family_id class_id
# 467  DF0000481.4      ERV1      LTR
# 468
#               DF family_id class_id
# 468  DF0000482.4      ERV1      LTR
# 469
#               DF family_id class_id
# 469  DF0000483.4      ERV1      LTR
# 470
#               DF family_id class_id
# 470  DF0000484.4      ERV1      LTR
# 471
#               DF family_id class_id
# 471  DF0000485.4      ERV1      LTR
# 472
#               DF family_id class_id
# 472  DF0000486.4      ERV1      LTR
# 473
#               DF family_id class_id
# 473  DF0000487.4      ERV1      LTR
# 474
#               DF family_id class_id
# 474  DF0000488.4      ERVL      LTR
# 475
#               DF family_id class_id
# 475  DF0000489.4      ERVL      LTR
# 476
#               DF family_id class_id
# 476  DF0000490.4      ERVL      LTR
# 477
#               DF family_id class_id
# 477  DF0000491.4      ERVL      LTR
# 478
#               DF family_id class_id
# 478  DF0000492.4      ERVL      LTR
# 479
#               DF family_id class_id
# 479  DF0000493.4      ERVL      LTR
# 480
#               DF family_id class_id
# 480  DF0000494.4      ERV1      LTR
# 481
#               DF family_id class_id
# 481  DF0000495.4      ERV1      LTR
# 482
#               DF family_id class_id
# 482  DF0000496.4      ERV1      LTR
# 483
#               DF family_id class_id
# 483  DF0000497.4      ERV1      LTR
# 484
#               DF family_id class_id
# 484  DF0000498.4      ERV1      LTR
# 485
#               DF family_id class_id
# 485  DF0000499.4      ERV1      LTR
# 486
#               DF family_id class_id
# 486  DF0000500.4      ERV1      LTR
# 487
#               DF family_id class_id
# 487  DF0000501.4      ERV1      LTR
# 488
#               DF family_id class_id
# 488  DF0000502.4      ERV1      LTR
# 489
#               DF family_id class_id
# 489  DF0000503.4      ERV1      LTR
# 490
#               DF family_id class_id
# 490  DF0000504.4      ERV1      LTR
# 491
#               DF family_id class_id
# 491  DF0000505.4      ERV1      LTR
# 492
#               DF family_id class_id
# 492  DF0000506.4      ERV1      LTR
# 493
#               DF family_id class_id
# 493  DF0000507.4      ERV1      LTR
# 494
#             DF family_id class_id
# 494  DF0000508      ERV1      LTR
# 495
#               DF family_id class_id
# 495  DF0000509.4      ERVK      LTR
# 496
#               DF family_id class_id
# 496  DF0000510.4      ERVK      LTR
# 497
#               DF family_id class_id
# 497  DF0000511.4      ERVK      LTR
# 498
#               DF family_id class_id
# 498  DF0000512.4      ERV1      LTR
# 499
#               DF family_id class_id
# 499  DF0000513.4      ERVL      LTR
# 500
#               DF family_id class_id
# 500  DF0000514.4      ERVL      LTR
# 501
#               DF family_id class_id
# 501  DF0000515.4      ERVL      LTR
# 502
#               DF family_id class_id
# 502  DF0000516.4      ERVL      LTR
# 503
#               DF family_id class_id
# 503  DF0000517.4      ERVL      LTR
# 504
#               DF family_id class_id
# 504  DF0000518.4      ERVL      LTR
# 505
#               DF family_id class_id
# 505  DF0000519.4      ERVL      LTR
# 506
#               DF family_id class_id
# 506  DF0000520.4      ERVL      LTR
# 507
#               DF family_id class_id
# 507  DF0000521.4      ERV1      LTR
# 508
#               DF family_id class_id
# 508  DF0000522.4      ERV1      LTR
# 509
#               DF family_id class_id
# 509  DF0000523.4      ERV1      LTR
# 510
#               DF family_id class_id
# 510  DF0000524.4      ERV1      LTR
# 511
#               DF family_id class_id
# 511  DF0000525.4      ERV1      LTR
# 512
#               DF family_id class_id
# 512  DF0000526.4      ERV1      LTR
# 513
#               DF family_id class_id
# 513  DF0000527.4      ERV1      LTR
# 514
#               DF family_id class_id
# 514  DF0000528.4      ERV1      LTR
# 515
#             DF family_id class_id
# 515  DF0000529      ERV1      LTR
# 516
#               DF family_id class_id
# 516  DF0000530.4      ERVL      LTR
# 517
#               DF family_id class_id
# 517  DF0000531.4      ERVL      LTR
# 518
#               DF family_id class_id
# 518  DF0000532.4      ERVL      LTR
# 519
#               DF family_id class_id
# 519  DF0000533.4      ERVL      LTR
# 520
#               DF family_id class_id
# 520  DF0000534.4      ERVL      LTR
# 521
#               DF family_id class_id
# 521  DF0000535.4      ERVL      LTR
# 522
#               DF family_id class_id
# 522  DF0000536.4      ERV1      LTR
# 523
#               DF family_id class_id
# 523  DF0000537.4      ERV1      LTR
# 524
#               DF family_id class_id
# 524  DF0000538.4      ERV1      LTR
# 525
#             DF family_id class_id
# 525  DF0000539      ERV1      LTR
# 526
#               DF family_id class_id
# 526  DF0000540.4      ERVK      LTR
# 527
#               DF family_id class_id
# 527  DF0000541.4      ERVL      LTR
# 528
#               DF family_id class_id
# 528  DF0000542.4      ERV1      LTR
# 529
#               DF family_id class_id
# 529  DF0000543.4      ERVL      LTR
# 530
#               DF family_id class_id
# 530  DF0000544.4      ERVL      LTR
# 531
#               DF family_id class_id
# 531  DF0000545.4      ERVL      LTR
# 532
#               DF family_id class_id
# 532  DF0000546.4      ERVL      LTR
# 533
#               DF family_id class_id
# 533  DF0000547.4      ERVL      LTR
# 534
#               DF family_id class_id
# 534  DF0000548.4      ERV1      LTR
# 535
#               DF family_id class_id
# 535  DF0000549.4      ERV1      LTR
# 536
#               DF family_id class_id
# 536  DF0000550.4      ERVL      LTR
# 537
#               DF family_id class_id
# 537  DF0000551.4      ERV1      LTR
# 538
#               DF family_id class_id
# 538  DF0000552.4      ERVL      LTR
# 539
#               DF family_id class_id
# 539  DF0000553.4      ERVL      LTR
# 540
#               DF family_id class_id
# 540  DF0000554.4      ERV1      LTR
# 541
#               DF family_id class_id
# 541  DF0000555.4      ERV1      LTR
# 542
#               DF family_id class_id
# 542  DF0000556.4      ERVK      LTR
# 543
#               DF family_id class_id
# 543  DF0000557.4      ERVK      LTR
# 544
#               DF family_id class_id
# 544  DF0000558.4      ERVK      LTR
# 545
#               DF family_id class_id
# 545  DF0000559.4      ERV1      LTR
# 546
#               DF family_id class_id
# 546  DF0000560.4      ERV1      LTR
# 547
#               DF family_id class_id
# 547  DF0000561.4      ERV1      LTR
# 548
#               DF family_id class_id
# 548  DF0000562.4      ERVL      LTR
# 549
#               DF family_id class_id
# 549  DF0000563.4      ERV1      LTR
# 550
#               DF family_id class_id
# 550  DF0000564.4      ERV1      LTR
# 551
#               DF family_id class_id
# 551  DF0000565.4      ERVL      LTR
# 552
#               DF family_id class_id
# 552  DF0000566.4      ERVL      LTR
# 553
#               DF family_id class_id
# 553  DF0000567.4      ERV1      LTR
# 554
#               DF family_id class_id
# 554  DF0000568.4      ERVL      LTR
# 555
#               DF family_id class_id
# 555  DF0000569.4      ERV1      LTR
# 556
#               DF family_id class_id
# 556  DF0000570.4      ERV1      LTR
# 557
#               DF family_id class_id
# 557  DF0000571.4      ERV1      LTR
# 558
#               DF family_id class_id
# 558  DF0000572.4      ERV1      LTR
# 559
#               DF family_id class_id
# 559  DF0000573.4      ERV1      LTR
# 560
#               DF family_id class_id
# 560  DF0000574.4      ERV1      LTR
# 561
#               DF family_id class_id
# 561  DF0000575.4      ERV1      LTR
# 562
#               DF family_id class_id
# 562  DF0000576.4      ERV1      LTR
# 563
#               DF family_id class_id
# 563  DF0000577.4      ERV1      LTR
# 564
#               DF family_id class_id
# 564  DF0000578.4      ERVL      LTR
# 565
#               DF family_id class_id
# 565  DF0000579.4      ERV1      LTR
# 566
#               DF family_id class_id
# 566  DF0000580.4      ERVL      LTR
# 567
#               DF family_id class_id
# 567  DF0000581.4      ERV1      LTR
# 568
#               DF family_id class_id
# 568  DF0000582.4      ERV1      LTR
# 569
#               DF family_id class_id
# 569  DF0000583.4      ERV1      LTR
# 570
#               DF family_id class_id
# 570  DF0000584.4      ERV1      LTR
# 571
#               DF family_id class_id
# 571  DF0000585.4      ERVL      LTR
# 572
#               DF family_id class_id
# 572  DF0000587.4      ERV1      LTR
# 573
#               DF family_id class_id
# 573  DF0000588.4      ERV1      LTR
# 574
#               DF family_id class_id
# 574  DF0000589.4      ERV1      LTR
# 575
#               DF family_id class_id
# 575  DF0000590.4      ERV1      LTR
# 576
#               DF family_id class_id
# 576  DF0000591.4      ERVL      LTR
# 577
#               DF family_id class_id
# 577  DF0000592.4      ERVL      LTR
# 578
#               DF family_id class_id
# 578  DF0000593.4     Gypsy      LTR
# 579
#               DF family_id class_id
# 579  DF0000594.4     Gypsy      LTR
# 580
#               DF family_id class_id
# 580  DF0000595.4     Gypsy      LTR
# 581
#               DF family_id class_id
# 581  DF0000596.4     Gypsy      LTR
# 582
#               DF family_id class_id
# 582  DF0000597.4     Gypsy      LTR
# 583
#               DF family_id class_id
# 583  DF0000598.4      ERVL      LTR
# 584
#               DF family_id class_id
# 584  DF0000599.4      ERVL      LTR
# 585
#               DF family_id class_id
# 585  DF0000600.4      ERVL      LTR
# 586
#               DF family_id class_id
# 586  DF0000601.4      ERVL      LTR
# 587
#               DF family_id class_id
# 587  DF0000602.4      ERVL      LTR
# 588
#               DF family_id class_id
# 588  DF0000603.4     Gypsy      LTR
# 589
#               DF family_id class_id
# 589  DF0000604.4     Gypsy      LTR
# 590
#               DF family_id class_id
# 590  DF0000605.4     Gypsy      LTR
# 591
#               DF family_id class_id
# 591  DF0000606.4      ERVL      LTR
# 592
#               DF family_id class_id
# 592  DF0000607.4      ERVL      LTR
# 593
#               DF family_id class_id
# 593  DF0000608.4      ERVL      LTR
# 594
#               DF family_id class_id
# 594  DF0000609.4      ERVL      LTR
# 595
#               DF family_id class_id
# 595  DF0000610.4      ERVL      LTR
# 596
#               DF family_id class_id
# 596  DF0000611.4      ERVL      LTR
# 597
#               DF family_id class_id
# 597  DF0000612.4     Gypsy      LTR
# 598
#               DF family_id class_id
# 598  DF0000613.4     Gypsy      LTR
# 599
#               DF family_id class_id
# 599  DF0000614.4     Gypsy      LTR
# 600
#               DF family_id class_id
# 600  DF0000615.4      ERVL      LTR
# 601
#               DF family_id class_id
# 601  DF0000616.4      ERV1      LTR
# 602
#               DF family_id class_id
# 602  DF0000617.4      ERV1      LTR
# 603
#               DF family_id class_id
# 603  DF0000618.4      ERV1      LTR
# 604
#               DF                                          family_id class_id
# ...
# 1142  DF0001167.2  TcMar-Tc1      DNA
# 1143
#                DF   family_id class_id
# 1143  DF0001168.2  hAT-Tip100      DNA
# 1144
#                DF family_id class_id
# 1144  DF0001169.2       Alu     SINE
# 1145
#                DF  family_id class_id
# 1145  DF0001170.2  TcMar-Tc1      DNA
# 1146
#                DF family_id class_id
# 1146  DF0001171.2     Gypsy      LTR
# 1147
#                DF family_id class_id
# 1147  DF0001172.2    hAT-Ac      DNA
# 1148
#                DF                         family_id class_id
# 1148  DF0001173.2  root;Interspersed_Repeat;Unknown  Unknown
# 1149
#                DF family_id class_id
# 1149  DF0001174.2       Alu     SINE
# 1150
#                DF family_id class_id
# 1150  DF0001175.2       hAT      DNA
# 1151
#                DF    family_id class_id
# 1151  DF0001176.2  hAT-Charlie      DNA
# 1152
#                DF family_id class_id
# 1152  DF0001177.2  RTE-BovB     LINE
# 1153
#                DF  family_id class_id
# 1153  DF0001178.2  hAT-hAT19      DNA
# 1154
#                DF    family_id class_id
# 1154  DF0001179.2  hAT-Charlie      DNA
# 1155
#                DF                                          family_id class_id
# 1155  DF0001180.2  root;Interspersed_Repeat;Transposable_Element;...      DNA
# 1156
#                DF                         family_id class_id
# 1156  DF0001181.2  root;Interspersed_Repeat;Unknown  Unknown
# 1157
#                DF                                          family_id class_id
# 1157  DF0001183.2  root;Interspersed_Repeat;Transposable_Element;...      LTR
# 1158
#                DF family_id class_id
# 1158  DF0001184.2    L1-Tx1     LINE
# 1159
#                DF                         family_id class_id
# 1159  DF0001185.2  root;Interspersed_Repeat;Unknown  Unknown
# 1160
#                DF                                          family_id class_id
# 1160  DF0001186.2  root;Interspersed_Repeat;Transposable_Element;...      LTR
# 1161
#                DF                         family_id class_id
# 1161  DF0001187.2  root;Interspersed_Repeat;Unknown  Unknown
# 1162
#                DF      family_id class_id
# 1162  DF0001188.2  hAT-Blackjack      DNA
# 1163
#                DF                         family_id class_id
# 1163  DF0001189.2  root;Interspersed_Repeat;Unknown  Unknown
# 1164
#                DF                                          family_id class_id
# 1164  DF0001190.2  root;Interspersed_Repeat;Transposable_Element;...      LTR
# 1165
#                DF     family_id class_id
# 1165  DF0001191.2  TcMar-Tigger      DNA
# 1166
#                DF   family_id class_id
# 1166  DF0001192.2  hAT-Tip100      DNA
# 1167
#                DF    family_id class_id
# 1167  DF0001193.2  hAT-Charlie      DNA
# 1168
#                DF   family_id class_id
# 1168  DF0001194.2  hAT-Tip100      DNA
# 1169
#                DF                         family_id class_id
# 1169  DF0001195.2  root;Interspersed_Repeat;Unknown  Unknown
# 1170
#                DF     family_id class_id
# 1170  DF0001196.2  TcMar-Tigger      DNA
# 1171
#                DF family_id class_id
# 1171  DF0001197.2       Alu     SINE
# 1172
#                DF family_id class_id
# 1172  DF0001198.2        L2     LINE
# 1173
#                DF    family_id class_id
# 1173  DF0001199.2  hAT-Charlie      DNA
# 1174
#                DF     family_id class_id
# 1174  DF0001200.2  TcMar-Tigger      DNA
# 1175
#                DF family_id class_id
# 1175  DF0001201.2     Gypsy      LTR
# 1176
#                DF                         family_id class_id
# 1176  DF0001202.2  root;Interspersed_Repeat;Unknown  Unknown
# 1177
#                DF     family_id class_id
# 1177  DF0001203.2  TcMar-Tigger      DNA
# 1178
#                DF                         family_id class_id
# 1178  DF0001204.2  root;Interspersed_Repeat;Unknown  Unknown
# 1179
#                DF                         family_id class_id
# 1179  DF0001205.2  root;Interspersed_Repeat;Unknown  Unknown
# 1180
#                DF  family_id class_id
# 1180  DF0001206.2  MULE-MuDR      DNA
# 1181
#                DF    family_id class_id
# 1181  DF0001207.2  hAT-Charlie      DNA
# 1182
#                DF family_id class_id
# 1182  DF0001208.2  Penelope     LINE
# 1183
#                DF    family_id class_id
# 1183  DF0001209.2  hAT-Charlie      DNA
# 1184
#                DF                         family_id class_id
# 1184  DF0001210.2  root;Interspersed_Repeat;Unknown  Unknown
# 1185
#                DF family_id class_id
# 1185  DF0001211.2    hAT-Ac      DNA
# 1186
#                DF                         family_id class_id
# 1186  DF0001212.2  root;Interspersed_Repeat;Unknown  Unknown
# 1187
#                DF family_id class_id
# 1187  DF0001213.2       hAT      DNA
# 1188
#                DF                                          family_id class_id
# 1188  DF0001214.2  root;Interspersed_Repeat;Transposable_Element;...      DNA
# 1189
#                DF family_id class_id
# 1189  DF0001215.2        L2     LINE
# 1190
#                DF family_id class_id
# 1190  DF0001216.2       CR1     LINE
# 1191
#                DF family_id class_id
# 1191  DF0001217.2      ERV1      LTR
# 1192
#                DF family_id class_id
# 1192  DF0001218.2       CR1     LINE
# 1193
#                DF                                          family_id class_id
# 1193  DF0001219.2  root;Interspersed_Repeat;Transposable_Element;...      DNA
# 1194
#                DF family_id class_id
# 1194  DF0001220.2      ERV1      LTR
# 1195
#                DF  family_id class_id
# 1195  DF0001221.2  ERVL-MaLR      LTR
# 1196
#                DF     family_id class_id
# 1196  DF0001222.2  TcMar-Tigger      DNA
# 1197
#                DF family_id class_id
# 1197  DF0001223.2       hAT      DNA
# 1198
#                DF      family_id class_id
# 1198  DF0001224.2  TcMar-Mariner      DNA
# 1199
#                DF     family_id class_id
# 1199  DF0001225.2  TcMar-Tigger      DNA
# 1200
#                DF                         family_id class_id
# 1200  DF0001226.2  root;Interspersed_Repeat;Unknown  Unknown
# 1201
#                DF                         family_id class_id
# 1201  DF0001227.2  root;Interspersed_Repeat;Unknown  Unknown
# 1202
#                DF family_id class_id
# 1202  DF0001228.2      ERVL      LTR
# 1203
#                DF     family_id class_id
# 1203  DF0001229.2  TcMar-Tigger      DNA
# 1204
#                DF  family_id class_id
# 1204  DF0001231.2  TcMar-Tc1      DNA
# 1205
#                DF                         family_id class_id
# 1205  DF0001232.2  root;Interspersed_Repeat;Unknown  Unknown
# 1206
#                DF family_id class_id
# 1206  DF0001233.2      ERVL      LTR
# 1207
#                DF                                          family_id class_id
# 1207  DF0001234.2  root;Interspersed_Repeat;Transposable_Element;...      LTR
# 1208
#                DF family_id class_id
# 1208  DF0001235.2  I-Jockey     LINE
# 1209
#                DF   family_id class_id
# 1209  DF0001236.2  hAT-Tip100      DNA
# 1210
#                DF family_id class_id
# 1210  DF0001237.2       hAT      DNA
# 1211
#                DF  family_id class_id
# 1211  DF0001238.2  TcMar-Tc1      DNA
# 1212
#                DF                                          family_id class_id
# 1212  DF0001239.2  root;Interspersed_Repeat;Transposable_Element;...      DNA
# 1213
#                DF family_id class_id
# 1213  DF0001240.2       Alu     SINE
# 1214
#                DF     family_id class_id
# 1214  DF0001241.2  TcMar-Tigger      DNA
# 1215
#                DF     family_id class_id
# 1215  DF0001242.2  TcMar-Tigger      DNA
# 1216
#                DF   family_id class_id
# 1216  DF0001243.2  hAT-Tip100      DNA
# 1217
#                DF    family_id class_id
# 1217  DF0001244.2  hAT-Charlie      DNA
# 1218
#                DF   family_id class_id
# 1218  DF0001245.2  hAT-Tip100      DNA
# 1219
#                DF                         family_id class_id
# 1219  DF0001246.2  root;Interspersed_Repeat;Unknown  Unknown
# 1220
#                DF                         family_id class_id
# 1220  DF0001247.2  root;Interspersed_Repeat;Unknown  Unknown
# 1221
#                DF family_id class_id
# 1221  DF0001248.2     TcMar      DNA
# 1222
#                DF    family_id class_id
# 1222  DF0001249.2  hAT-Charlie      DNA
# 1223
#                DF family_id class_id
# 1223  DF0001250.2        L2     LINE
# 1224
#                DF     family_id class_id
# 1224  DF0001251.2  TcMar-Tigger      DNA
# 1225
#                DF family_id class_id
# 1225  DF0001252.2       CR1     LINE
# 1226
#                DF family_id class_id
# 1226  DF0001253.2       MIR     SINE
# 1227
#                DF   family_id class_id
# 1227  DF0001254.2  hAT-Tip100      DNA
# 1228
#                DF  family_id class_id
# 1228  DF0001256.2  ERVL-MaLR      LTR
# 1229
#                DF                                          family_id class_id
# 1229  DF0001258.2  root;Interspersed_Repeat;Transposable_Element;...      LTR
# 1230
#                DF     family_id class_id
# 1230  DF0001259.2  TcMar-Tigger      DNA
# 1231
#                DF                         family_id class_id
# 1231  DF0001260.2  root;Interspersed_Repeat;Unknown  Unknown
# 1232
#                DF    family_id class_id
# 1232  DF0001261.2  hAT-Charlie      DNA
# 1233
#                DF   family_id class_id
# 1233  DF0001262.2  hAT-Tip100      DNA
# 1234
#                DF                         family_id class_id
# 1234  DF0001263.2  root;Interspersed_Repeat;Unknown  Unknown
# 1235
#                DF  family_id class_id
# 1235  DF0001264.2  MULE-MuDR      DNA
# 1236
#                DF family_id class_id
# 1236  DF0001265.2       CR1     LINE
# 1237
#                DF                                          family_id class_id
# 1237  DF0001266.2  root;Interspersed_Repeat;Transposable_Element;...      LTR
# 1238
#                DF                         family_id class_id
# 1238  DF0001267.2  root;Interspersed_Repeat;Unknown  Unknown
# 1239
#                DF family_id class_id
# 1239  DF0001270.2       hAT      DNA
# 1240
#                DF                         family_id class_id
# 1240  DF0001272.2  root;Interspersed_Repeat;Unknown  Unknown
# 1241
#                DF                         family_id class_id
# 1241  DF0001273.2  root;Interspersed_Repeat;Unknown  Unknown
# 1242
#                DF                                          family_id class_id
# 1242  DF0001274.2  root;Interspersed_Repeat;Transposable_Element;...      DNA
# 1243
#                DF family_id class_id
# 1243  DF0001275.2    hAT-Ac      DNA
# 1244
#                DF   family_id class_id
# 1244  DF0001276.2  hAT-Tip100      DNA
# 1245
#                DF                         family_id class_id
# 1245  DF0001277.2  root;Interspersed_Repeat;Unknown  Unknown
# 1246
#                DF family_id class_id
# 1246  DF0001278.2      ERV1      LTR
# 1247
#                DF                                          family_id class_id
# 1247  DF0001279.2  root;Interspersed_Repeat;Transposable_Element;...      DNA
# 1248
#                DF family_id class_id
# 1248  DF0001280.2        L2     LINE
# 1249
#                DF     family_id class_id
# 1249  DF0001281.2  TcMar-Tigger      DNA
# 1250
#                DF                                          family_id class_id
# 1250  DF0001282.2  root;Interspersed_Repeat;Transposable_Element;...      DNA
# 1251
#                DF                         family_id class_id
# 1251  DF0001283.2  root;Interspersed_Repeat;Unknown  Unknown
# 1252
#                DF     family_id class_id
# 1252  DF0001285.2  TcMar-Tigger      DNA
# 1253
#                DF   family_id class_id
# 1253  DF0001286.2  hAT-Tip100      DNA
# 1254
#                DF family_id class_id
# 1254  DF0001288.2   Crypton      DNA
# 1255
#                DF                         family_id class_id
# 1255  DF0001289.2  root;Interspersed_Repeat;Unknown  Unknown
# 1256
#                DF   family_id class_id
# 1256  DF0001290.2  hAT-Tip100      DNA
# 1257
#                DF family_id class_id
# 1257  DF0001291.2       CR1     LINE
# 1258
#                DF                                          family_id class_id
# 1258  DF0001292.2  root;Interspersed_Repeat;Transposable_Element;...      DNA
# 1259
#                DF family_id class_id
# 1259  DF0001293.2  hAT-Tag1      DNA
# 1260
#                DF family_id class_id
# 1260  DF0001294.2  Helitron       RC
# 1261
#                DF                                          family_id class_id
# 1261  DF0001295.2  root;Interspersed_Repeat;Transposable_Element;...      DNA
# 1262
#                DF                                          family_id class_id
# 1262  DF0001296.2  root;Interspersed_Repeat;Transposable_Element;...      LTR
# 1263
#                DF   family_id class_id
# 1263  DF0001297.2  hAT-Tip100      DNA
# 1264
#                DF   family_id class_id
# 1264  DF0001298.2  hAT-Tip100      DNA
# 1265
#                DF     family_id class_id
# 1265  DF0001299.2  TcMar-Tigger      DNA
# 1266
#                DF family_id class_id
# 1266  DF0001300.2       CR1     LINE
# 1267
#                DF                         family_id class_id
# 1267  DF0001301.2  root;Interspersed_Repeat;Unknown  Unknown
# 1268
#                DF family_id class_id
# 1268  DF0001303.2      ERV1      LTR
# 1269
#                DF family_id class_id
# 1269  DF0001304.2     Gypsy      LTR
# 1270
#                DF     family_id class_id
# 1270  DF0001305.2  TcMar-Tigger      DNA
# 1271
#                DF                                          family_id class_id
# 1271  DF0001307.2  root;Interspersed_Repeat;Transposable_Element;...      DNA
# 1272
#                DF                                          family_id class_id
# 1272  DF0001308.2  root;Interspersed_Repeat;Transposable_Element;...      DNA
# 1273
#                DF     family_id class_id
# 1273  DF0001309.2  TcMar-Tigger      DNA
# 1274
#              DF family_id class_id
# 1274  DF0001310      ERV1      LTR
# 1275
#                DF                                          family_id class_id
# 1275  DF0001311.2  root;Interspersed_Repeat;Transposable_Element;...      DNA
# 1276
#                DF                         family_id class_id
# 1276  DF0001312.2  root;Interspersed_Repeat;Unknown  Unknown
# 1277
#                DF    family_id class_id
# 1277  DF0001313.2  hAT-Charlie      DNA
# 1278
#                DF     family_id class_id
# 1278  DF0001314.2  TcMar-Tigger      DNA
# 1279
#                DF family_id class_id
# 1279  DF0001316.2       Alu     SINE
# 1280
#                DF family_id class_id
# 1280  DF0001317.2       Alu     SINE
# 1281
#                DF family_id class_id
# 1281  DF0001318.2       Alu     SINE
# 1282
#                DF family_id class_id
# 1282  DF0001320.2       Alu     SINE
# 1283
#                DF family_id class_id
# 1283  DF0001321.2       Alu     SINE
# 1284
#                DF      family_id class_id
# 1284  DF0001323.2  PIF-Harbinger      DNA
# 1285
#                DF family_id class_id
# 1285  DF0001325.2       CR1     LINE
# 1286
#                DF family_id class_id
# 1286  DF0001326.2       CR1     LINE
# 1287
#                DF family_id class_id
# 1287  DF0001327.2       CR1     LINE
# 1288
#                DF family_id class_id
# 1288  DF0001328.2       CR1     LINE
# 1289
#                DF family_id class_id
# 1289  DF0001331.2        L2     LINE
# 1290
#                DF family_id class_id
# 1290  DF0001333.2        L2     LINE
# 1291
#                DF family_id class_id
# 1291  DF0001334.2        L2     LINE
# 1292
#                DF family_id class_id
# 1292  DF0001335.2  hAT-Tag1      DNA
# 1293
#                DF family_id class_id
# 1293  DF0001336.2       CR1     LINE
# 1294
#                DF family_id class_id
# 1294  DF0001337.2      ERV1      LTR
# 1295
#              DF    family_id class_id
# 1295  DF0001423  tRNA-Deu-L2     SINE
# 1296
#              DF                                     family_id class_id
# 1296  DF0001428  root;Interspersed_Repeat;Pseudogene;RNA;rRNA     rRNA
# 1297
#                DF      family_id class_id
# 1297  DF0001731.0  PIF-Harbinger      DNA
# 1298
#                DF family_id class_id
# 1298  DF0001732.0        L2     LINE
# 1299
#                DF                         family_id class_id
# 1299  DF0002200.0  root;Interspersed_Repeat;Unknown  Unknown
# 1300
#                DF      family_id class_id
# 1300  DF0003796.0  PIF-Harbinger      DNA
# 1301
#              DF family_id class_id
# 1301  DF0004193       CR1     LINE
# 1302
#              DF family_id class_id
# 1302  DF0006271      DIRS      LTR
# 1303
#              DF family_id class_id
# 1303  DF0006272      DIRS      LTR
# done
# (1304, 3)

# %%
print(df.shape)
print(df.head())
# Out:
# (1304, 3)
#             DF     family_id class_id
# 0  DF0000001.4           MIR     SINE
# 1  DF0000002.4           Alu     SINE
# 2  DF0000003.4           Alu     SINE
# 3  DF0000004.4  TcMar-Tigger      DNA
# 4  DF0000005.4     ERVL-MaLR      LTR

# %% [markdown]
# merge the hits data with the family and class ids

# %%
full_hits = pd.merge(hits, df, left_on = "family_acc", right_on = "DF", how = "left")

print("original hits df size:")
print(hits.shape)
print("new hits df size:")
print(full_hits.shape)
print(full_hits.head())
# Out:
# original hits df size:
# (5657545, 15)
# new hits df size:
# (5657545, 18)
#   #seq_name   family_acc  family_name   bits        e-value  bias  hmm-st  \
# 0      chr1  DF0001137.4         TAR1  355.0  1.100000e-103  98.4    1206
# 1      chr1  DF0001137.4         TAR1  558.7  4.100000e-165  71.5     466
# 2      chr1  DF0000279.4  L1MC4a_3end   64.0   6.900000e-16   9.4     195
# 3      chr1  DF0000878.4        MER5B   35.7   1.300000e-05   7.2       1
# 4      chr1  DF0001253.2     MIR1_Amn   30.9   3.100000e-04   6.8      57
#
#    hmm-en strand  ali-st  ali-en  env-st  env-en     sq-len  kimura_div  \
# 0    1716      -   10954   10464   10964   10448  248956422        8.32
# 1    1114      -   11463   10826   11482   10810  248956422        6.74
# 2     395      -   11676   11502   11696   11480  248956422       17.98
# 3     105      -   11780   11677   11780   11657  248956422       22.20
# 4     149      -   15353   15265   15376   15248  248956422       18.87
#
#             DF     family_id   class_id
# 0  DF0001137.4  subtelomeric  Satellite
# 1  DF0001137.4  subtelomeric  Satellite
# 2  DF0000279.4            L1       LINE
# 3  DF0000878.4   hAT-Charlie        DNA
# 4  DF0001253.2           MIR       SINE

# %% [markdown]
# write to a file

# %%
full_hits.to_csv("{}/hg38_dfam_annotation.tsv".format(DOWNLOADDIR), index=False, sep='\t')

# %% [markdown]
# run the perl script with the new file

# %%
# %%bash -s "$DOWNLOADDIR" "$WRKDIR"
# DOWNLOADDIR=${1}
# WRKDIR=${2}
#
# perl ${WRKDIR}/makeTEgtf.PERL -c 1 -s 10 -e 11 -o 9 -t 3 -f 17 -C 18 -S 4 ${DOWNLOADDIR}/hg38_dfam_annotation.tsv > ${DOWNLOADDIR}/hg38_dfam_annotation.gtf

# %% [markdown]
# ### May need to swap start and end positions for lines with "-" strand for STAR alignment to work
# run this to switch the start and end position for rows with "-" for strand

# %%
#awk 'BEGIN {OFS=FS="\t"} $7=="-" {t = $4; $4 = $5; $5 = t; print; next};{print $0} ' hg38_dfam_annotation.gtf > hg38_dfam_annotation_swap.gtf

# %% [markdown]
# push the new gtf file to google cloud

# %%
print('run locally:')
print('gsutil cp {}/hg38_dfam_annotation.gtf {}/'.format(DOWNLOADDIR, GCRESOURCES))
# Out:
# run locally:
# gsutil cp /local/path/for/files/pipelinedownloads/hg38_dfam_annotation.gtf gs://bucketname/TEtranscriptsresources/

# %% [markdown]
# ### (c) Create gtf with hg19 HSATII converted to hg38

# %% [markdown]
# 1) download hg19 Repeatmasker from [UCSC Table Browser](http://genome.ucsc.edu/cgi-bin/hgTables?hgsid=779592275_N3CYal7CTJjbHIyobHuJvr25ifGf&clade=mammal&org=&db=hg19&hgta_group=rep&hgta_track=rmsk&hgta_table=rmsk&hgta_regionType=genome&position=&hgta_outputType=bed&hgta_outFileName=) with repeats group, repeatmasker track and BED format

# %%
print('curl "http://genome.ucsc.edu/cgi-bin/hgTables?hgsid=779592275_N3CYal7CTJjbHIyobHuJvr25ifGf&boolshad.hgta_printCustomTrackHeaders=0&hgta_ctName=tb_rmsk&hgta_ctDesc=table+browser+query+on+rmsk&hgta_ctVis=pack&hgta_ctUrl=&fbQual=whole&fbUpBases=200&fbDownBases=200&hgta_doGetBed=get+BED" -o {}/hg19_rmsk.bed'.format(DOWNLOADDIR))
# Out:
# curl "http://genome.ucsc.edu/cgi-bin/hgTables?hgsid=779592275_N3CYal7CTJjbHIyobHuJvr25ifGf&boolshad.hgta_printCustomTrackHeaders=0&hgta_ctName=tb_rmsk&hgta_ctDesc=table+browser+query+on+rmsk&hgta_ctVis=pack&hgta_ctUrl=&fbQual=whole&fbUpBases=200&fbDownBases=200&hgta_doGetBed=get+BED" -o /local/directory/for/files/pipelinedownloads/hg19_rmsk.bed

# %% [markdown]
# 2) extract HSATII elements from BED file

# %%
print("grep HSATII {}/hg19_rmsk.bed > {}/HSATII_hg19_rmsk.bed".format(DOWNLOADDIR,DOWNLOADDIR))
# Out:
# grep HSATII /local/directory/for/files/pipelinedownloads/hg19_rmsk.bed > /local/directory/for/files/pipelinedownloads/HSATII_hg19_rmsk.bed

# %% [markdown]
# 3) convert the HSATII hg19 elements to hg38 using the liftover tool: https://genome.ucsc.edu/cgi-bin/hgLiftOver

# %% [markdown]
# 4) convert the lifted over HSATII file to a gtf file

# %% [markdown]
# ```awk '{print $1"\t""hg19_rmsk""\t""exon""\t"($2+1)"\t"$3"\t"$5"\t"$6"\t"".""\t""gene_id \""$4"\"; transcript_id \""$4"\";"}' HSATII_liftover.bed > HSATII_liftover.gtf```

# %% [markdown]
# 5) download hg38 Repeatmasker from [UCSC Table Browser](http://genome.ucsc.edu/cgi-bin/hgTables?hgsid=779592275_N3CYal7CTJjbHIyobHuJvr25ifGf&clade=mammal&org=&db=hg38&hgta_group=rep&hgta_track=rmsk&hgta_table=rmsk&hgta_regionType=genome&position=&hgta_outputType=gtf&hgta_outFileName=) with repeats group, repeatmasker track and GTF format

# %% [markdown]
# 6) get the elements that do not overlap with HSATII

# %%
print("module load bedtools")
print("bedtools intersect -a hg38_rmsk.gtf -b HSATII_liftover.gtf -v > no_overlap.gtf")
# Out:
# module load bedtools
# bedtools intersect -a hg38_rmsk.gtf -b HSATII_liftover.gtf -v > no_overlap.gtf

# %% [markdown]
# 7) merge the no overlap file with the HSATII liftover elements

# %%
print("cat no_overlap.gtf HSATII_liftover.gtf > custom_HSATII_annotation.gtf")
# Out:
# cat no_overlap.gtf HSATII_liftover.gtf > custom_HSATII_annotation.gtf

# %% [markdown]
# 8) push new file to google cloud

# %%
print('run locally:')
print('gsutil cp {}/custom_HSATII_annotation.gtf {}/'.format(DOWNLOADDIR, GCRESOURCES))
# Out:
# run locally:
# gsutil cp /local/directory/for/files/pipelinedownloads/custom_HSATII_annotation.gtf gs://bucketname/TEtranscriptsresources/

# %% [markdown]
# # (3) Setup STAR
# (Spliced Transcripts Alignment to a Reference)
#
# indexed reference genome files are on biowulf here: ```/fdb/STAR_current```
#
# run these commands to copy (some of the files are soft linked so pushing the folder to gc may not work)

# %%
print("navigate here on biowulf:")
print("cd /fdb/STAR_current/UCSC/hg38")
# Out:
# navigate here on biowulf:
# cd /fdb/STAR_current/UCSC/hg38

# %%
BIOWULFTEMPDIR = "/biowulf/temporary/directory/for/ref/genome/files"

print("mkdir {}/ref".format(BIOWULFTEMPDIR))
print("cp /fdb/STAR_current/UCSC/hg38/ref/chrLength.txt {}/ref/".format(BIOWULFTEMPDIR))
print("cp /fdb/STAR_current/UCSC/hg38/ref/chrNameLength.txt {}/ref/".format(BIOWULFTEMPDIR))
print("cp /fdb/STAR_current/UCSC/hg38/ref/chrName.txt {}/ref/".format(BIOWULFTEMPDIR))
print("cp /fdb/STAR_current/UCSC/hg38/ref/chrStart.txt {}/ref/".format(BIOWULFTEMPDIR))
print("cp /fdb/STAR_indices/repo/Genome/c33f343609537f34364ba535438dc9237064327b97fcdc76636f9d1c4d08f739 {}/ref/Genome".format(BIOWULFTEMPDIR))
print("cp /fdb/STAR_current/UCSC/hg38/ref/genomeParameters.txt {}/ref/".format(BIOWULFTEMPDIR))
print("cp /fdb/STAR_indices/repo/SA/cdf66cb5d1a4f1346c066c21568c1a3b48ede6b8e89c1afcd06249247a673080 {}/ref/SA".format(BIOWULFTEMPDIR))
print("cp /fdb/STAR_indices/repo/SAindex/552dd6491165ccfb1f9b4236f1664720f47e9adf395a451e657b768b18cbc1a5 {}/ref/SAindex".format(BIOWULFTEMPDIR))
print("compress the folder:")
print("cd {}".format(BIOWULFTEMPDIR))
print("tar czf {}/ref.tar.gz ref".format(BIOWULFTEMPDIR))
# Out:
# mkdir /biowulf/temporary/directory/for/ref/genome/files/ref
# cp /fdb/STAR_current/UCSC/hg38/ref/chrLength.txt /biowulf/temporary/directory/for/ref/genome/files/ref/
# cp /fdb/STAR_current/UCSC/hg38/ref/chrNameLength.txt /biowulf/temporary/directory/for/ref/genome/files/ref/
# cp /fdb/STAR_current/UCSC/hg38/ref/chrName.txt /biowulf/temporary/directory/for/ref/genome/files/ref/
# cp /fdb/STAR_current/UCSC/hg38/ref/chrStart.txt /biowulf/temporary/directory/for/ref/genome/files/ref/
# cp /fdb/STAR_indices/repo/Genome/c33f343609537f34364ba535438dc9237064327b97fcdc76636f9d1c4d08f739 /biowulf/temporary/directory/for/ref/genome/files/ref/Genome
# cp /fdb/STAR_current/UCSC/hg38/ref/genomeParameters.txt /biowulf/temporary/directory/for/ref/genome/files/ref/
# cp /fdb/STAR_indices/repo/SA/cdf66cb5d1a4f1346c066c21568c1a3b48ede6b8e89c1afcd06249247a673080 /biowulf/temporary/directory/for/ref/genome/files/ref/SA
# cp /fdb/STAR_indices/repo/SAindex/552dd6491165ccfb1f9b4236f1664720f47e9adf395a451e657b768b18cbc1a5 /biowulf/temporary/directory/for/ref/genome/files/ref/SAindex
# compress the folder:
# cd /biowulf/temporary/directory/for/ref/genome/files
# tar czf /biowulf/temporary/directory/for/ref/genome/files/ref.tar.gz ref

# %%
print("log into google cloud via biowulf:")
print("module load google-cloud-sdk")
print("gcloud auth login")

print("")

print("follow login instructions and then run command to push archived file to google cloud:")

print("gsutil cp \
ref.tar.gz \
{}/".format(GCRESOURCES))
# Out:
# log into google cloud via biowulf:
# module load google-cloud-sdk
# gcloud auth login
#
# follow login instructions and then run command to push archived file to google cloud:
# gsutil cp ref.tar.gz gs://bucketname/TEtranscriptsresources/

# %% [markdown]
# # (4) Build and push docker image
# docker must be installed locally (https://docs.docker.com/docker-for-mac/install/)

# %%
print("run this locally at terminal in folder of dockerfile:")
print("docker build -t tetranscripts-image .")

print("\ntag the image to point it to the google cloud project:")
print("docker tag tetranscripts-image:latest us.gcr.io/{}/tetranscripts-image".format(PROJECT_ID))

print("\npush the image to google cloud:")
print("docker push us.gcr.io/{}/tetranscripts-image".format(PROJECT_ID))

print("\ncheck 'Container Registry' in gcc to find the new image")
# Out:
# run this locally at terminal in folder of dockerfile:
# docker build -t tetranscripts-image .
#
# tag the image to point it to the google cloud project:
# docker tag tetranscripts-image:latest us.gcr.io/projectid/tetranscripts-image
#
# push the image to google cloud:
# docker push us.gcr.io/projectid/tetranscripts-image
#
# check 'Container Registry' in gcc to find the new image

# %% [markdown]
# #### once pushed find the container on google cloud and copy its full path
# something like:
#
# ```us.gcr.io/projectid/test-image@sha256:04bc2af3cccd8618e6eafadc7d46e7fb24b2dc89e0e62ea0bdb26865d081f632```

# %% [markdown]
# paste the full path name into the input.json file wherever a docker variable is set
#
# like
#
# ```"TEtranscriptsWorkflow.dockerimg": "us.gcr.io/projectid/test-image@sha256:04bc2af3cccd8618e6eafadc7d46e7fb24b2dc89e0e62ea0bdb26865d081f632"```

# %% [markdown]
# # (5) Setup Cromwell server for running in parallel

# %% [markdown]
# pull down cromwell server setup scripts from gcp

# %%
CROMWELL_SCRIPT_BUCKET="gs://somebucketname/tools/verily-amp-pd-source"

# %%
print("gsutil -mq cp -r {} {}".format(CROMWELL_SCRIPT_BUCKET,DOWNLOADDIR))
# Out:
# gsutil -mq cp -r gs://somebucketname/tools/verily-amp-pd-source /local/path/for/files/pipelinedownloads

# %%
print('\n#fire up the cromwell instance')
print('chmod +x {}/verily-amp-pd-source/setup_cromwell_vm/*.sh'.format(DOWNLOADDIR))
print('cd {}/verily-amp-pd-source/setup_cromwell_vm/'.format(DOWNLOADDIR))
print('./create_cromwell_server.sh {}-cromwell {} n1-highmem-8'\
      .format(COHORT,PROJECT_ID))

print('./configure.sh {}-cromwell {} nihnialngcbg-testing/{}'\
      .format(COHORT,PROJECT_ID,COHORT.replace('_','-')))
# Out:
# #fire up the cromwell instance
# chmod +x /local/path/for/files/pipelinedownloads/verily-amp-pd-source/setup_cromwell_vm/*.sh
# cd /local/path/for/files/pipelinedownloads/verily-amp-pd-source/setup_cromwell_vm/
# ./create_cromwell_server.sh cohort-cromwell projectid n1-highmem-8
# ./configure.sh cohort-cromwell projectid nihnialngcbg-testing/cohort

# %%
print('\n#When that is up, ssh to the instance:')
print('gcloud --project {} compute ssh {}-cromwell'.format(PROJECT_ID,COHORT.replace('_','-')))
# Out:
# #When that is up, ssh to the instance:
# gcloud --project projectid compute ssh cohort-cromwell

# %%
print('\n#And in that SSH session, run:')
print('cd /install')
print('docker-compose -f /install/workspace/config/docker-compose.yml up')
# Out:
# #And in that SSH session, run:
# cd /install
# docker-compose -f /install/workspace/config/docker-compose.yml up

# %% [markdown]
# #### create the ssh tunnel to the cromwell server so you can submit jobs

# %%
print('#When cromwell is up, create an SSH tunnel from your workstation:')
print('#run these commands at terminal:\n')
print('gcloud --project {} compute ssh {}-cromwell -- -L 8000:localhost:8000'\
      .format(PROJECT_ID,COHORT.replace('_','-')))

print('\n#after this runs you will actually be logged into the cromwell server, ' \
      'so you will need to open another terminal session on your machine to submit your jobs\n')
# Out:
# #When cromwell is up, create an SSH tunnel from your workstation:
# #run these commands at terminal:
#
# gcloud --project projectid compute ssh cohort-cromwell -- -L 8000:localhost:8000
#
# #after this runs you will actually be logged into the cromwell server, so you will need to open another terminal session on your machine to submit your jobs

# %% [markdown]
# #  (6) Setup input files

# %% [markdown]
# #### get list of sample ids

# %%
SAMPLE_BUCKET='gs://some/bucket/with/fastqs'

# %% [markdown]
# #### see what fastqs are in the bucket

# %%
# %%bash -s "$SAMPLE_BUCKET"
# SAMPLE_BUCKET=${1}
#
# gsutil ls ${SAMPLE_BUCKET} | wc -l
# Out:
#      622

# %% [markdown]
# #### get fastqs listing

# %%
# %%bash -s "$DOWNLOADDIR" "$SAMPLE_BUCKET" "$COHORT"
# DOWNLOADDIR=${1}
# SAMPLE_BUCKET=${2}
#
# FASTQ_LISTING=${DOWNLOADDIR}/fastqs.fastq.listing.txt
#
# gsutil ls ${SAMPLE_BUCKET}/*.fastq.gz > ${FASTQ_LISTING}
#
# sed -i -e s"/gs:\/\/some\/bucket\/with\/fastqs\///"g ${FASTQ_LISTING}
# sed -i -e s"/\.fastq\.gz//"g ${FASTQ_LISTING}
# sed -i -e s'/_R/\,R/'g ${FASTQ_LISTING}
#
# less ${FASTQ_LISTING} | wc -l
# head ${FASTQ_LISTING}
# Out:
#      622
# KEN1003fctx,R1
# KEN1003fctx,R2
# KEN1066fctx,R1
# KEN1066fctx,R2
# KEN1069fctx,R1
# KEN1069fctx,R2
# KEN1070fctx,R1
# KEN1070fctx,R2
# KEN1092fctx,R1
# KEN1092fctx,R2

# %%
import pandas as pd
fastqdf=pd.read_csv("{}/fastqs.fastq.listing.txt".format(DOWNLOADDIR),header=None)
fastqdf.columns = ['ID','READ']
print(fastqdf.shape)
fastqdf.head()
# Out:
# (622, 2)
#             ID READ
# 0  KEN1003fctx   R1
# 1  KEN1003fctx   R2
# 2  KEN1066fctx   R1
# 3  KEN1066fctx   R2
# 4  KEN1069fctx   R1

# %%
sample_ids = fastqdf['ID'].unique()
print(sample_ids.shape)
# Out:
# (311,)

# %% [markdown]
# #### (optional) subset for testing

# %%
sample_ids = sample_ids[:3]
print(sample_ids.shape)
print(sample_ids)
# Out:
# (3,)
# ['KEN1003fctx' 'KEN1066fctx' 'KEN1069fctx']

# %% [markdown]
# #### create the per sample json files
# ### SPECIFY WHICH ANNOTATION TO USE HERE

# %%
import json
json_label_template = '{}/templates/blank.tetranscripts.label.json'.format(WRKDIR)
json_input_template = '{}/templates/blank.tetranscripts.input.json'.format(WRKDIR)
json_options_template = '{}/templates/blank.tetranscripts.options.json'.format(WRKDIR)

for sample_id in sample_ids:
    json_label_outfile_name = '{}/jsons/{}.label.json'.format(WRKDIR,sample_id)
    json_input_outfile_name = '{}/jsons/{}.input.json'.format(WRKDIR,sample_id)
    json_options_outfile_name = '{}/jsons/{}.options.json'.format(WRKDIR,sample_id)
    
    with open(json_label_template) as json_file:
        label_data = json.load(json_file)
        
        label_data['cohort'] = COHORT.lower()
        label_data['sample'] = sample_id.lower()
        label_data['user'] = USER.lower()
        
        with open(json_label_outfile_name, 'w') as json_outfile:
            json.dump(label_data,json_outfile,sort_keys=True,indent=4)
            
    with open(json_options_template) as json_file:
        options_data = json.load(json_file)
        
        options_data['final_call_logs_dir'] = "{}/logs/{}".format(GCOUTPUT,sample_id)
        options_data['final_workflow_log_dir'] = "{}/logs/{}".format(GCOUTPUT,sample_id)
        options_data['final_workflow_outputs_dir'] = "{}/output/{}".format(GCOUTPUT,sample_id)
        
        with open(json_options_outfile_name, 'w') as json_outfile:
            json.dump(options_data,json_outfile,sort_keys=True,indent=4)
    with open(json_input_template) as json_file:
        input_data = json.load(json_file)
        
        input_data['TEtranscriptsWorkflow.sample_name'] = sample_id.lower()
        input_data['TEtranscriptsWorkflow.firstPairedEnd'] = "{}/{}_R1.fastq.gz".format(SAMPLE_BUCKET, sample_id)
        input_data['TEtranscriptsWorkflow.secondPairedEnd'] = "{}/{}_R2.fastq.gz".format(SAMPLE_BUCKET, sample_id)
        
        input_data['TEtranscriptsWorkflow.gene_annotation_gtf'] = "{}/hg38_gene_annotation.gtf".format(GCRESOURCES)
        input_data['TEtranscriptsWorkflow.refgenomeFile'] = "{}/ref.tar.gz".format(GCRESOURCES)
        #ANNOTATION TO USE:
        input_data['TEtranscriptsWorkflow.TE_annotation_gtf'] = "{}/custom_HSATII_annotation.gtf".format(GCRESOURCES)
        
        with open(json_input_outfile_name, 'w') as json_outfile:
            json.dump(input_data,json_outfile,sort_keys=True,indent=4)

# %% [markdown]
# #### function to format the command

# %%
def formatgcpcmd(this_sample):
    this_cmd = 'echo -n {SAMPLE} \n\
python {DOWNLOADDIR}/verily-amp-pd-source/wdl_workflow_runner/cromwell_client.py \
--wdl {WRKDIR}/TEtranscript_count_pipeline.wdl \
--workflow-inputs {WRKDIR}/jsons/{SAMPLE}.input.json \
--workflow-options {WRKDIR}/jsons/{SAMPLE}.options.json \
--workflow-labels {WRKDIR}/jsons/{SAMPLE}.label.json'
    return(this_cmd.format(DOWNLOADDIR=DOWNLOADDIR,WRKDIR=WRKDIR,SAMPLE=this_sample))

# %% [markdown]
# #### make a command for each sample and write it to a file

# %%
cmds = [formatgcpcmd(sample_id) for sample_id in sample_ids]

temp_script_file = '{}/run_TEtranscripts.sh'.format(WRKDIR)

with open(temp_script_file, 'w') as file_handler:
    for this_cmd in cmds:
        file_handler.write("{}\n".format(this_cmd))

# %% [markdown]
# # (7) Run TEtranscripts

# %%
print('#run these commands at terminal:\n')
print('chmod +x ' + temp_script_file)
print('nohup ' + temp_script_file + ' > {}/run_TEtranscripts.log &'.format(WRKDIR))
# Out:
# #run these commands at terminal:
#
# chmod +x /local/directory/for/files/run_TEtranscripts.sh
# nohup /local/directory/for/files/run_TEtranscripts.sh > /local/directory/for/files/run_TEtranscripts.log &

# %% [markdown]
# # (8) Monitor the jobs

# %%
#see how many GCE (Google Compute Engine) instances are running your jobs


print('#full job worker node count')
# !gcloud compute instances list --project {PROJECT_ID} \
--filter "labels:({COHORT} {USER})" | grep RUNNING | wc -l

print('#number of all running instances in project')
# !gcloud compute instances list --project {PROJECT_ID} | grep RUNNING | wc -l
# Out:
# #full job worker node count
# Listed 0 items.
#        0
# #number of all running instances in project
#        1

# %%
print('#run these commands at terminal:\n')

print('#When cromwell is up, create an SSH tunnel from your workstation, if not already connected:\n')
print('gcloud --project {} compute ssh {}-cromwell -- -L 8000:localhost:8000'.\
      format(PROJECT_ID,COHORT.replace('_','-')))

print('\n#if tunnel established can check cromwell status\n')
print('curl -X GET "http://localhost:8000/api/workflows/v1/query?status=Running"')
print('curl -X GET "http://localhost:8000/api/workflows/v1/query?status=Submitted"')
print('curl -X GET "http://localhost:8000/api/workflows/v1/query?status=Failed"')
print('curl -X GET "http://localhost:8000/api/workflows/v1/query?status=Succeeded"')
# Out:
# #run these commands at terminal:
#
# #When cromwell is up, create an SSH tunnel from your workstation, if not already connected:
#
# gcloud --project projectid compute ssh cohort-cromwell -- -L 8000:localhost:8000
#
# #if tunnel established can check cromwell status
#
# curl -X GET "http://localhost:8000/api/workflows/v1/query?status=Running"
# curl -X GET "http://localhost:8000/api/workflows/v1/query?status=Submitted"
# curl -X GET "http://localhost:8000/api/workflows/v1/query?status=Failed"
# curl -X GET "http://localhost:8000/api/workflows/v1/query?status=Succeeded"

# %% [markdown]
# # (9) Gather output

# %%
LOCAL_OUTPUT="/local/directory/to/store/output"

# %%
print("run locally:")
print("gsutil cp -r {}/output/ {}".format(GCOUTPUT, LOCAL_OUTPUT))
print("cd {}".format(LOCAL_OUTPUT))
print("find . -iname '*.cntTable' -exec cp {} . \;")

print("rm -r {}/output/".format(LOCAL_OUTPUT))
# Out:
# run locally:
# gsutil cp -r gs://bucketname/output/output/ /Users/grennfp/TEtranscript_project/test_output
# cd /Users/grennfp/TEtranscript_project/test_output
# find . -iname '*.cntTable' -exec cp {} . \;
# rm -r /Users/grennfp/TEtranscript_project/test_output/output/
